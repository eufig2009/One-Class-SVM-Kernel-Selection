# %%
# %pylab inline
from useful_function import *
from sklearn.svm import SVDD
import pandas as pd
from sklearn.metrics import roc_auc_score
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['sample', 'gamma', 'clf', 'test', 'cholesky']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def slice_probability_metric(clf, train_x, rho=0.111111):
    clf.fit(train_x)
    positive_error = mean(clf.predict(train_x) == -1)
    positive_error /= (1 + rho)
    synthetic_anomalies = rand(1000, train_x.shape[1]) - 0.5
    synthetic_anomalies *= 4 * (train_x.max() - train_x.min())
    negative_errors = mean(clf.predict(synthetic_anomalies) == 1)
    negative_errors *= rho/(1 + rho)
    return negative_errors + positive_error

# %%
train_x = generate_dataset(10000, dim=2)
train, test = split_data_set(train_x, 2)
inliers, outliers = split_anomaly_normal_data(test, outliers_fraction=0.1)
train = train.iloc[:, :-1]
test = test.iloc[:, :-1]

# %%
all_gammas = logspace(-10, 10, 50)

# %%
results_their = []
for gamma in all_gammas:
    C = (len(train_x) * 0.1) ** (-1)
    clf = SVDD(C=C,kernel='rbf', gamma=gamma)
    results_their.append(slice_probability_metric(clf, test))

# %%
def validate_classifier_by_random_points(all_gammas, train_x, size=1000):
    all_values = []
    positive_points = SMOTE(train_x, k=5,n_samples=size)
    negative_points = rand(size, train_x.shape[1]) - 0.5
    negative_points *= 4 * (train_x.max() - train_x.min())
    for gamma in all_gammas:
        C = 1.0 / len(train_x) / 0.1
        clf = SVDD(kernel='rbf', gamma=gamma, C=C)
        clf.fit(train_x)
        error = mean(clf.predict(positive_points) == -1)
        error += mean(clf.predict(negative_points) == 1)
        all_values.append(error)
    return all_values

# %%
results_our = validate_classifier_by_random_points(all_gammas, train)

# %%
results_auc = []
for gamma in all_gammas:
    C = (len(train_x) * 0.1) ** (-1)
    clf = SVDD(C=C, kernel='rbf', gamma=gamma).fit(train)
    results = mean(clf.predict(inliers) == -1)
    results += mean(clf.predict(outliers * 50) == 1)
    #results = -1 * concatenate([clf.decision_function(inliers), clf.decision_function(outliers)])
    #true_results = [0] * len(inliers) + [1] * len(outliers)
    #error = roc_auc_score(true_results, results, average='weighted')
    results_auc.append(results)

# %%
figsize(10, 7)
plot(all_gammas, results_their,'bs', label='Slice')
plot(all_gammas, results_their,'bs', label='Slice')
plot(all_gammas, results_our, 'bo', label='SMOTE')
plot(all_gammas, results_our, 'b')
plot(all_gammas, results_auc, 'b^', label='Test Error')
plot(all_gammas, results_auc, 'b')

legend(loc='best')
xlabel('gamma')
ylabel('Score')
grid(True)
xscale('log')

# %%
def process_data_set(data):
    normal_data, anomaly_data = split_anomaly_normal_data(data)
    selection_technics = [validate_classifier_by_random_points, slice_probability_metric]
    normal_train, normal_validate, normal_test = split_data_set(normal_data, 3)
    anomaly_train, anomaly_validate, anomaly_test = split_data_set(anomaly_data, 3)
    results = {}
    all_gammas = np.logspace(-10, 10, 50)
    for technic in selection_technics:
        start = time.time()
        metrics = model_selection(concatenate([normal_validate, anomaly_validate]), all_gammas, technic)
        duration = time.time() - start
        best_index = np.argmin(metrics)
        best_score = metrics[best_index]
        all_best_gamma = metrics == best_score
        possible_results = all_gammas[all_best_gamma]
        best_gamma = np.max(possible_results)
        fn, fp, auc = validate_gamma(concatenate([normal_train, anomaly_train]), normal_test, anomaly_test, best_gamma)
        results[str(technic).split()[1]] = {'false negative': fn, 'false positive': fp, 'auc': auc, 'time':duration}
    return results

# %%
results = {}
for data_set in os.listdir('./csv_data_set/'):
    try:
        data = pd.read_csv('./csv_data_set/{}'.format(data_set))
        tmp = process_data_set(data)
        print tmp
        results[data_set] = tmp
    except:
        pass
# Out:
# {'slice_probability_metric': {'false positive': 0.92233009708737868, 'auc': 0.40012749903330652, 'false negative': 0.017222820236813777, 'time': 8.842736959457397}, 'validate_classifier_by_random_points': {'false positive': 0.86407766990291257, 'auc': 0.37854672003511447, 'false negative': 0.051668460710441337, 'time': 71.82713103294373}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.90000000000000002, 'false negative': 1.0, 'time': 0.02032613754272461}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 3.397092819213867}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.92500000000000004, 'false negative': 0.61458333333333337, 'time': 0.07831788063049316}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.92500000000000004, 'false negative': 0.61458333333333337, 'time': 5.274726867675781}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.06314492225646973}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.51810237203495635, 'false negative': 1.0, 'time': 3.5659680366516113}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.12090086936950684}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.81909090909090909, 'false negative': 0.95999999999999996, 'time': 11.533476114273071}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.50751879699248126, 'false negative': 0.98496240601503759, 'time': 1.019747018814087}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.80665950590762603, 'false negative': 0.98496240601503759, 'time': 81.12870979309082}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.63111111111111118, 'false negative': 0.9555555555555556, 'time': 0.031295061111450195}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.62666666666666671, 'false negative': 1.0, 'time': 3.918147087097168}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.74650493421052622, 'false negative': 0.83552631578947367, 'time': 0.14356613159179688}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.97080592105263164, 'false negative': 0.25657894736842107, 'time': 8.125396966934204}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.21077394485473633}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.87, 'false negative': 0.84999999999999998, 'time': 14.195003986358643}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.88235294117647056, 'false negative': 0.17647058823529413, 'time': 0.03317594528198242}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.88235294117647056, 'false negative': 0.17647058823529413, 'time': 3.263763904571533}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.1875, 'time': 0.018970966339111328}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.125, 'time': 2.6635589599609375}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.88461538461538458, 'false negative': 0.65384615384615385, 'time': 0.02511119842529297}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.96153846153846156, 'false negative': 0.84615384615384615, 'time': 7.191692113876343}}
# {'slice_probability_metric': {'false positive': 0.88888888888888884, 'auc': 0.82804232804232802, 'false negative': 0.083333333333333329, 'time': 0.07494592666625977}, 'validate_classifier_by_random_points': {'false positive': 0.77777777777777779, 'auc': 0.45238095238095244, 'false negative': 0.36904761904761907, 'time': 19.064977884292603}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.50757575757575757, 'false negative': 0.98484848484848486, 'time': 0.04550814628601074}, 'validate_classifier_by_random_points': {'false positive': 0.42857142857142855, 'auc': 0.53246753246753253, 'false negative': 0.51515151515151514, 'time': 4.386115074157715}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.22560975609756098, 'false negative': 0.97560975609756095, 'time': 0.02979302406311035}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 4.353255033493042}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.01754307746887207}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.5, 'time': 1.9035828113555908}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.90664556962025311, 'false negative': 0.93670886075949367, 'time': 0.3890810012817383}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.90585443037974678, 'false negative': 1.0, 'time': 52.673606872558594}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.0644841194152832}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 8.976689100265503}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.9375, 'false negative': 0.625, 'time': 0.0240170955657959}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.9375, 'false negative': 0.9375, 'time': 2.799443006515503}}
# {'slice_probability_metric': {'false positive': 0.64640883977900554, 'auc': 0.8189164925733301, 'false negative': 0.075748320097739769, 'time': 17.36935806274414}, 'validate_classifier_by_random_points': {'false positive': 0.65745856353591159, 'auc': 0.81409025403564672, 'false negative': 0.081246182040317652, 'time': 56.98994517326355}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.65656565656565646, 'false negative': 0.90909090909090906, 'time': 1.3499000072479248}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.66666666666666652, 'false negative': 1.0, 'time': 573.3780539035797}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.80000000000000004, 'false negative': 1.0, 'time': 0.020231962203979492}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 3.4219510555267334}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.62903225806451613, 'false negative': 0.74193548387096775, 'time': 0.030277013778686523}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.62903225806451613, 'false negative': 0.74193548387096775, 'time': 8.258592128753662}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.53846153846153844, 'false negative': 0.76923076923076927, 'time': 0.020952939987182617}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 5.0339789390563965}}
# {'slice_probability_metric': {'false positive': 0.59999999999999998, 'auc': 0.39200000000000002, 'false negative': 0.46000000000000002, 'time': 0.053665876388549805}, 'validate_classifier_by_random_points': {'false positive': 0.59999999999999998, 'auc': 0.39200000000000002, 'false negative': 0.46000000000000002, 'time': 6.730443000793457}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.76923076923076927, 'false negative': 0.92307692307692313, 'time': 0.11890292167663574}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.61538461538461542, 'false negative': 0.38461538461538464, 'time': 126.77513003349304}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.96875, 'false negative': 1.0, 'time': 0.018056869506835938}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.1875, 'time': 2.3374621868133545}}
# {'slice_probability_metric': {'false positive': 0.5, 'auc': 0.45454545454545453, 'false negative': 0.36363636363636365, 'time': 0.01785588264465332}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.27272727272727271, 'false negative': 1.0, 'time': 1.9956541061401367}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.46666666666666667, 'false negative': 1.0, 'time': 0.3718280792236328}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.46666666666666667, 'false negative': 1.0, 'time': 380.91104388237}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.78260869565217395, 'time': 0.020240068435668945}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.78260869565217395, 'time': 2.5609309673309326}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.6875, 'false negative': 1.0, 'time': 0.017076969146728516}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.9375, 'false negative': 1.0, 'time': 1.670881986618042}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.66666666666666663, 'false negative': 1.0, 'time': 0.2989518642425537}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 266.3394320011139}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 3.704078197479248}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.99624060150375937, 'false negative': 0.96992481203007519, 'time': 304.7212209701538}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.87878787878787878, 'false negative': 1.0, 'time': 0.03669404983520508}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.84848484848484851, 'false negative': 0.90909090909090906, 'time': 7.60682487487793}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.027330875396728516}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 3.3588318824768066}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.6875, 'false negative': 0.9375, 'time': 0.017504215240478516}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 1.8773279190063477}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.10967493057250977}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 16.05573010444641}}
# {'slice_probability_metric': {'false positive': 0.090909090909090912, 'auc': 0.72999999999999987, 'false negative': 0.66000000000000003, 'time': 0.1191709041595459}, 'validate_classifier_by_random_points': {'false positive': 0.090909090909090912, 'auc': 0.72999999999999987, 'false negative': 0.66000000000000003, 'time': 10.8296639919281}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.87096774193548399, 'false negative': 0.77419354838709675, 'time': 0.02262401580810547}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.88172043010752688, 'false negative': 0.64516129032258063, 'time': 3.8561160564422607}}
# {'slice_probability_metric': {'false positive': 0.7142857142857143, 'auc': 0.25850340136054428, 'false negative': 0.58730158730158732, 'time': 0.05242609977722168}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 5.240140199661255}}
# {'slice_probability_metric': {'false positive': 1.0, 'auc': 0.25, 'false negative': 0.375, 'time': 0.02923297882080078}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.58333333333333326, 'false negative': 0.96875, 'time': 8.26233696937561}}
# {'slice_probability_metric': {'false positive': 0.40000000000000002, 'auc': 0.50222222222222224, 'false negative': 0.59999999999999998, 'time': 0.031301021575927734}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 4.259352922439575}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 1.0, 'time': 0.017791032791137695}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 2.226759195327759}}
# {'slice_probability_metric': {'false positive': 0.5, 'auc': 0.42261904761904756, 'false negative': 0.52380952380952384, 'time': 0.03766512870788574}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.2857142857142857, 'false negative': 0.90476190476190477, 'time': 7.3125159740448}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.52676923076923077, 'false negative': 1.0, 'time': 0.30345702171325684}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.52676923076923077, 'false negative': 1.0, 'time': 17.9828519821167}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.88077336197636946, 'false negative': 0.94736842105263153, 'time': 3.71989107131958}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.87540279269602561, 'false negative': 1.0, 'time': 320.8503739833832}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.024190902709960938}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.97530864197530864, 'false negative': 1.0, 'time': 6.991393089294434}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.9229588508605957}, 'validate_classifier_by_random_points': {'false positive': 0.64150943396226412, 'auc': 0.61892272762859157, 'false negative': 0.24273858921161826, 'time': 14.069278955459595}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.79555555555555557, 'false negative': 1.0, 'time': 0.03695511817932129}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.88444444444444437, 'false negative': 1.0, 'time': 9.460206985473633}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.92666666666666664, 'false negative': 0.56000000000000005, 'time': 0.08186578750610352}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 9.059646129608154}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.625, 'time': 0.01813793182373047}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 1.9670400619506836}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 0.020846843719482422}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 2.032857894897461}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.875, 'false negative': 0.5625, 'time': 0.018072128295898438}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.875, 'false negative': 0.5625, 'time': 2.0794739723205566}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.9857068061828613}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.88077336197636946, 'false negative': 1.0, 'time': 81.37244606018066}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.9872419834136963}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.67508055853920512, 'false negative': 1.0, 'time': 74.09730792045593}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.50375939849624063, 'false negative': 0.99248120300751874, 'time': 0.9813899993896484}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.93447905477980664, 'false negative': 0.87969924812030076, 'time': 73.68651604652405}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.9862489700317383}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.76100966702470463, 'false negative': 1.0, 'time': 76.66236209869385}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.9375, 'time': 0.01764392852783203}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.6875, 'time': 2.0465939044952393}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.93722943722943719, 'false negative': 0.60606060606060608, 'time': 0.04262089729309082}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.93722943722943719, 'false negative': 0.60606060606060608, 'time': 5.73698616027832}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.71604938271604945, 'false negative': 0.33333333333333331, 'time': 0.019370079040527344}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 1.8367350101470947}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.06286311149597168}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.96145124716553287, 'false negative': 0.65079365079365081, 'time': 27.37013292312622}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.90909090909090906, 'false negative': 0.81818181818181823, 'time': 0.050733089447021484}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.90909090909090906, 'false negative': 0.81818181818181823, 'time': 9.00743317604065}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.6875, 'time': 0.01683497428894043}, 'validate_classifier_by_random_points': {'false positive': 1.0, 'auc': 0.1875, 'false negative': 0.0, 'time': 1.676142930984497}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.50375939849624063, 'false negative': 1.0, 'time': 4.794028043746948}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.98174006444683137, 'false negative': 1.0, 'time': 303.3721570968628}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.6875, 'false negative': 0.6875, 'time': 0.017993927001953125}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.6875, 'false negative': 0.9375, 'time': 1.9470229148864746}}
# {'slice_probability_metric': {'false positive': 0.5, 'auc': 0.45945945945945948, 'false negative': 0.24324324324324326, 'time': 0.040522098541259766}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 10.271363019943237}}
# {'slice_probability_metric': {'false positive': 0.8571428571428571, 'auc': 0.60204081632653061, 'false negative': 0.0, 'time': 0.05331301689147949}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.46122448979591835, 'false negative': 1.0, 'time': 5.399749040603638}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.51041666666666663, 'false negative': 0.97916666666666663, 'time': 0.026156187057495117}, 'validate_classifier_by_random_points': {'false positive': 0.59999999999999998, 'auc': 0.61250000000000004, 'false negative': 0.33333333333333331, 'time': 3.486496925354004}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 0.027297019958496094}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 2.1452221870422363}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.50375939849624063, 'false negative': 0.99248120300751874, 'time': 1.0653131008148193}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.81149301825993558, 'false negative': 1.0, 'time': 84.48917603492737}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.95238095238095233, 'false negative': 0.52380952380952384, 'time': 0.02360987663269043}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 1.0, 'time': 6.1692469120025635}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.88888888888888884, 'false negative': 0.88888888888888884, 'time': 0.016244888305664062}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.66666666666666663, 'false negative': 0.33333333333333331, 'time': 1.3007991313934326}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.34210526315789469, 'false negative': 0.78947368421052633, 'time': 0.02016305923461914}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 2.7701528072357178}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.60869565217391308, 'false negative': 0.82608695652173914, 'time': 0.02273082733154297}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.54347826086956519, 'false negative': 1.0, 'time': 2.456465005874634}}
# {'slice_probability_metric': {'false positive': 0.875, 'auc': 0.58159722222222221, 'false negative': 0.083333333333333329, 'time': 0.06666207313537598}, 'validate_classifier_by_random_points': {'false positive': 0.25, 'auc': 0.81944444444444431, 'false negative': 0.18055555555555555, 'time': 6.0850629806518555}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 0.01798081398010254}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 2.399027109146118}}
# {'slice_probability_metric': {'false positive': 0.73469387755102045, 'auc': 0.71012078300708037, 'false negative': 0.07029478458049887, 'time': 0.8711159229278564}, 'validate_classifier_by_random_points': {'false positive': 0.51020408163265307, 'auc': 0.59132768753760012, 'false negative': 0.37868480725623582, 'time': 13.715159177780151}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.65217391304347827, 'false negative': 1.0, 'time': 0.017578125}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.93478260869565211, 'false negative': 0.13043478260869565, 'time': 2.471369981765747}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 0.027944087982177734}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 6.134561061859131}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.88687059209447283, 'false negative': 1.0, 'time': 0.9371209144592285}, 'validate_classifier_by_random_points': {'false positive': 0.40384615384615385, 'auc': 0.71375266524520253, 'false negative': 0.3347547974413646, 'time': 13.984183073043823}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 1.0, 'false negative': 0.8125, 'time': 0.01767897605895996}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 2.2794039249420166}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.64759036144578308, 'false negative': 1.0, 'time': 0.19180679321289062}, 'validate_classifier_by_random_points': {'false positive': 0.27777777777777779, 'auc': 0.59236947791164662, 'false negative': 0.74096385542168675, 'time': 8.146728038787842}}
# {'slice_probability_metric': {'false positive': 0.91044776119402981, 'auc': 0.66694672333695759, 'false negative': 0.091059602649006616, 'time': 4.181412935256958}, 'validate_classifier_by_random_points': {'false positive': 0.79104477611940294, 'auc': 0.62693980428980911, 'false negative': 0.13079470198675497, 'time': 47.156049966812134}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.65625, 'false negative': 1.0, 'time': 0.017204999923706055}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 1.6721079349517822}}
# {'slice_probability_metric': {'false positive': 0.0, 'auc': 0.609375, 'false negative': 0.89583333333333337, 'time': 0.08332204818725586}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.609375, 'false negative': 0.89583333333333337, 'time': 5.28435206413269}}
# {'slice_probability_metric': {'false positive': 0.25, 'auc': 0.109375, 'false negative': 1.0, 'time': 0.05634307861328125}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.5, 'false negative': 1.0, 'time': 6.3575758934021}}
# {'slice_probability_metric': {'false positive': 0.21428571428571427, 'auc': 0.87755102040816324, 'false negative': 0.25563909774436089, 'time': 3.9279630184173584}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.84693877551020402, 'false negative': 1.0, 'time': 317.38516092300415}}
# {'slice_probability_metric': {'false positive': 0.375, 'auc': 0.61750000000000005, 'false negative': 0.46666666666666667, 'time': 0.043083906173706055}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': 0.52666666666666662, 'false negative': 1.0, 'time': 2.0332529544830322}}

# %%
def model_selection(data, all_gammas, selection_technic):
    metrics = zeros(all_gammas.shape[0])
    for index, gamma in enumerate(all_gammas):
        clf = SVDD(C = 1.0 / 100, gamma=gamma, kernel='rbf')
        metrics[index] = selection_technic(clf, data)
    return metrics

# %%
all_gammas
# Out:
# array([  1.00000000e-10,   2.55954792e-10,   6.55128557e-10,
#          1.67683294e-09,   4.29193426e-09,   1.09854114e-08,
#          2.81176870e-08,   7.19685673e-08,   1.84206997e-07,
#          4.71486636e-07,   1.20679264e-06,   3.08884360e-06,
#          7.90604321e-06,   2.02358965e-05,   5.17947468e-05,
#          1.32571137e-04,   3.39322177e-04,   8.68511374e-04,
#          2.22299648e-03,   5.68986603e-03,   1.45634848e-02,
#          3.72759372e-02,   9.54095476e-02,   2.44205309e-01,
#          6.25055193e-01,   1.59985872e+00,   4.09491506e+00,
#          1.04811313e+01,   2.68269580e+01,   6.86648845e+01,
#          1.75751062e+02,   4.49843267e+02,   1.15139540e+03,
#          2.94705170e+03,   7.54312006e+03,   1.93069773e+04,
#          4.94171336e+04,   1.26485522e+05,   3.23745754e+05,
#          8.28642773e+05,   2.12095089e+06,   5.42867544e+06,
#          1.38949549e+07,   3.55648031e+07,   9.10298178e+07,
#          2.32995181e+08,   5.96362332e+08,   1.52641797e+09,
#          3.90693994e+09,   1.00000000e+10])
