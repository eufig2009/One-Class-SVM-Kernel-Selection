# %%
# %pylab inline
from sklearn.svm import SVDD
from sklearn.metrics import pairwise_distances
import pandas as pd
from random import sample
import sys
import os
from sklearn.cross_validation import KFold
from scipy.linalg import cholesky
from sklearn.cross_validation import train_test_split 
from sklearn.metrics import roc_auc_score
from sklearn.utils import check_random_state
from scipy.spatial import cKDTree
from sklearn.utils import array2d
import time
nu = 0.1
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Data generation functions

# %%
def SMOTE(X, n_samples, k=5, dist_power=2, multiple=False, sample_weight=None,
          random_state=None):
    """
    Returns n_samples of synthetic samples from X generated by SMOTE.

    Parameters
    ----------
    X : array-like, shape = [n_minority_samples, n_features]
        Holds the minority samples
    n_samples : int
        Number of new synthetic samples.
    k : int
        Number of nearest neighbours.
    dist_power : float, int
        Positive power in ditance metrics.
    random_state : None or int
        Seed for random generator.


    Returns
    -------
    smoted_X : array, shape = [n_samples, n_features]
        Synthetic samples
    """
    
    if type(X) is pd.core.frame.DataFrame:
        X = X.values

    rng = check_random_state(random_state)
    n_minor, n_features = X.shape
    k = min([n_minor - 1, k])

    # Learn nearest neighbours
    nn_tree = cKDTree(X)

    if multiple:
        smoted_X = X.copy()
        if sample_weight is not None:
            weight_smoted = sample_weight.copy()
        nn_dist, nn_idx = nn_tree.query(smoted_X, k=k + 1, p=dist_power)
        nn_idx = nn_idx[:, 1:]
        for i in xrange(n_samples):
            start_idx = rng.choice(len(smoted_X))
            start = smoted_X[start_idx, :]
            end_idx = nn_idx[start_idx, rng.choice(k)]
            end = smoted_X[end_idx, :]
            shift = rng.rand()
            new_point = [start * shift + end * (1. - shift)]
            new_nn_idx = np.argsort(
                distance_matrix(smoted_X, new_point,
                                p=dist_power).T)[::-1][0][:k]
            smoted_X = np.vstack((smoted_X, new_point))
            nn_idx = np.vstack((nn_idx, new_nn_idx))
            if sample_weight is not None:
                weight_smoted = \
                    np.concatenate((weight_smoted,
                                    weight_smoted[start_idx] * shift +
                                    (1. - shift) * weight_smoted[end_idx]))

    else:
        start_indices = rng.choice(len(X), size=(n_samples,))
        starts = X[start_indices, :]
        nn_dists, nn_idx = nn_tree.query(starts, k=k + 1, p=dist_power)
        end_indices = nn_idx[np.arange(n_samples),
                             rng.choice(np.arange(1, k + 1), n_samples)]
        ends = X[end_indices, :]
        shifts = rng.rand(n_samples)
        smoted_X = starts * np.repeat(array2d(shifts).T, n_features, axis=1) \
            + ends * np.repeat(array2d(1. - shifts).T, n_features, axis=1)
        smoted_X = np.vstack((X, smoted_X))
        if sample_weight is not None:
            weight_smoted = sample_weight[start_indices] * shifts\
                + (1. - shifts) * sample_weight[end_indices]
    if sample_weight is None:
        return smoted_X
    else:
        return smoted_X, np.concatenate((sample_weight, weight_smoted))

# %%
def generate_synthetic_data(size, dim=2, centroid_count=2, centroid_dispersion=1):
    size = int(size)
    centroids = np.random.rand(centroid_count, dim) * 10 - 5
    all_data_part = []
    for point in centroids:
        covariation_matrix = np.random.randn(dim, dim)
        covariation_matrix = np.dot(covariation_matrix, covariation_matrix.T)
        covariation_matrix = cholesky(covariation_matrix)
        data_part = np.random.randn(int(size / centroid_count), dim)
        data_part = np.dot(data_part, covariation_matrix) + point
        all_data_part.append(data_part)
    data = np.concatenate(all_data_part, axis=0)
    return data

# %%
def generate_outlier(size, dim=2, space=1000):
    size = int(size)
    outliers = (np.random.rand(size, dim) - 0.5) * space * 2
    return outliers

# %%
def generate_dataset(size, outliers_part=0.12, dim=2, centroid_count=2, centroid_dispersion=1):
    inliers = generate_synthetic_data(size * (1 - outliers_part), 
                                               dim, centroid_count, 
                                               centroid_dispersion)
    outliers = generate_outlier(size*outliers_part, dim, space=centroid_dispersion*50)
    data = np.concatenate([inliers, outliers], axis=0)
    data = pd.DataFrame(data)
    data['label'] = ['target'] * len(inliers) + ['outlier'] * len(outliers)
    return data

# %% [markdown]
# #### Risk calculation functions

# %%
def validate_classifier_by_random_points(clf, train_x, size=10000):
    clf.fit(train_x)
    positive_points = SMOTE(train_x, k=5,n_samples=size)
    negative_points = np.random.rand(size, train_x.shape[1])
    negative_points *= np.std(train_x)
    error = mean(clf.predict(positive_points) == -1)
    error += mean(clf.predict(negative_points) == 1)
    return error

# %%
def rbf_kernel(X, Y, gamma):
    distance_matrix = pairwise_distances(X, Y) ** 2
    #print "Gamma = ", gamma
    distance_matrix = exp(-1 * gamma * distance_matrix)
    return distance_matrix

# %%
def calculate_radius(clf):
    all_support_vectors = clf.support_vectors_
    first_support_vector = clf.support_vectors_[0, :]
    dual_coef = clf.dual_coef_
    gamma = clf.gamma
    test_vector_norm = 1
    second_part = rbf_kernel(all_support_vectors, first_support_vector, gamma)
    #print "second_vector", second_part
    second_part = dot(dual_coef, second_part)
    #print second_part
    third_part = dot(dual_coef, dot(rbf_kernel(all_support_vectors, all_support_vectors, gamma), dual_coef.T))[0, 0]
    radius = (test_vector_norm - 2 * second_part + third_part)
    return radius[0, 0]

# %%
clf = SVDD(kernel='rbf', gamma=1).fit(train_x)
calculate_radius(clf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-583655bb3d4d> in <module>()
# ----> 1 clf = SVDD(kernel='rbf', gamma=1).fit(train_x)
#       2 calculate_radius(clf)
#
# NameError: name 'train_x' is not defined

# %%
rbf_kernel(support_vectors[0, :], support_vectors[1, :], clf.gamma)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-072a8107d9c5> in <module>()
# ----> 1 rbf_kernel(support_vectors[0, :], support_vectors[1, :], clf.gamma)
#
# NameError: name 'support_vectors' is not defined

# %%
def combinatorial_dimension_metric(clf, train_x):
    clf.fit(train_x)
    prediction = clf.decision_function(train_x)
    negative_marks = prediction < 0
    prediction = prediction[negative_marks]
    distance = prediction.min()
    radius = calculate_radius(clf)
    radius += abs(distance)
    return abs(distance) / radius
    
    
train_x = randn(100, 2)
clf = SVDD(kernel='rbf', gamma=0.001).fit(train_x)
combinatorial_dimension_metric(clf, train_x)
# Out:
# 0.030530754808307945

# %%
def kernel_metric(clf, train_x):
    gamma = clf.gamma
    distance = pairwise_distances(train_x)
    distance = distance * distance
    kernel_matrix = exp(-gamma * distance)
    kernel_matrix -= eye(kernel_matrix.shape[0])
    reguarization = 0.001
    return -var(kernel_matrix) / (mean(kernel_matrix) + reguarization)

# %%
def support_vectors_metric(clf, train_x):
    clf.fit(train_x)
    prediction = clf.predict(train_x)
    out_of_class_fraction = mean(prediction == -1)
    support_vectors_fraction = float(len(clf.support_vectors_)) / len(train_x)
    metric = (out_of_class_fraction - nu) ** 2
    metric += (support_vectors_fraction - nu) ** 2
    return metric

# %%
def slice_probability_space_metric(clf, train_x, folds_count=7):
    kf_iterator = KFold(len(data), n_folds=folds_count)
    metric = 0.0
    for train, test in kf_iterator:
        train_data = train_x[train,:]
        test_data = train_x[test,:]
        clf.fit(train_data)
        prediction = clf.predict(test_data)
        inlier_metric_part = mean(prediction == -1)
        inlier_metric_part = inlier_metric_part / (1 + rho) / len(data)
        outliers = outlier_distribution(*data.shape) - 0.5
        outliers *= 8 * np.std(train_x)
        outlier_metric_part = mean(clf.predict(outliers) == 1) * rho / (1 + rho) / len(outliers)
        metric += inlier_metric_part + outlier_metric_part
    return metric / folds_count

# %% [markdown]
# #### Selection function

# %%
all_gammas = np.logspace(-10, 10, 20)
def model_selection(data, all_gammas, selection_technic):
    metrics = zeros(all_gammas.shape[0])
    for index, gamma in enumerate(all_gammas):
        clf = SVDD(C = 1.0 / 100, gamma=gamma, kernel='rbf')
        metrics[index] = selection_technic(clf, data)
    return metrics

# %% [markdown]
# #### Example

# %%
synthetic_data = generate_dataset(100, centroid_count=2, outliers_part=0.1)
scatter(synthetic_data.iloc[:, 0], synthetic_data.iloc[:, 1])

# %%
all_gammas = np.logspace(-7, 7, 50)
metrics = model_selection(synthetic_data.iloc[:, :-1], all_gammas, kernel_metric)

# %%
print all_gammas
# Out:
# [  1.00000000e-07   1.93069773e-07   3.72759372e-07   7.19685673e-07
#    1.38949549e-06   2.68269580e-06   5.17947468e-06   1.00000000e-05
#    1.93069773e-05   3.72759372e-05   7.19685673e-05   1.38949549e-04
#    2.68269580e-04   5.17947468e-04   1.00000000e-03   1.93069773e-03
#    3.72759372e-03   7.19685673e-03   1.38949549e-02   2.68269580e-02
#    5.17947468e-02   1.00000000e-01   1.93069773e-01   3.72759372e-01
#    7.19685673e-01   1.38949549e+00   2.68269580e+00   5.17947468e+00
#    1.00000000e+01   1.93069773e+01   3.72759372e+01   7.19685673e+01
#    1.38949549e+02   2.68269580e+02   5.17947468e+02   1.00000000e+03
#    1.93069773e+03   3.72759372e+03   7.19685673e+03   1.38949549e+04
#    2.68269580e+04   5.17947468e+04   1.00000000e+05   1.93069773e+05
#    3.72759372e+05   7.19685673e+05   1.38949549e+06   2.68269580e+06
#    5.17947468e+06   1.00000000e+07]

# %%
plot(all_gammas, metrics)
xscale('log')

# %% [markdown]
# #### World's data processing

# %%
def split_anomaly_normal_data(data, outliers_fraction=0.1):
    outliers = data.query("label == 'outlier'")
    inliers = data.query("label == 'target'")
    outliers_count = int(len(inliers) * outliers_fraction / (1 - outliers_fraction))
    if outliers_count > len(outliers):
        raise ValueError("There are no so many outliers")
    outliers_rows = sample(outliers.index, outliers_count)
    selected_outliers = outliers.ix[outliers_rows]
    return inliers.iloc[:, :-1], selected_outliers.iloc[:, :-1]

# %%
def split_data_set(data, parts_count=3):
    all_parts = []
    kfold =KFold(len(data), n_folds=parts_count)
    for train, test in kfold:
        all_parts.append(data.iloc[test, :])
    return all_parts

# %% [markdown]
# #### Example

# %%
data = pd.read_csv('./csv_data_set/Iris (targetcl. Iris-setosa).csv')

# %%
metrics = model_selection(data.iloc[:, :-1], all_gammas, kernel_metric)

# %%
plot(all_gammas, metrics)
xscale('log')

# %% [markdown]
# #### Loading all data sets

# %%
def save_fig(all_gammas, metric, name):
    fig = figure()
    plot(all_gammas, metric)
    xscale('log')
    xlabel(r'$\gamma$')
    ylabel('metric')
    print name
    savefig(name)

# %% [markdown]
# #### Calculating metrics for every dataset

# %%
def validate_gamma(train, test_normal, test_anomaly, gamma):
    C = 1.0 / (0.1 * (len(train)))
    clf = SVDD(kernel='rbf', gamma=gamma, C=C)
    #clf.fit(np.random.randn(10000, 4))
    clf.fit(train)
    normal_data_prediction = clf.decision_function(test_normal)
    anomaly_data_prediction = clf.decision_function(test_anomaly)
    normal_data_error = np.mean(normal_data_prediction < 0)
    anomaly_data_error = np.mean(anomaly_data_prediction > 0)
    true_labels = [1] * len(test_normal) + [-1] * len(test_anomaly)
    decision_values = np.concatenate([normal_data_prediction, anomaly_data_prediction], axis=0)
    auc_score = auc_score(true_labels, decision_values)
    return normal_data_error, anomaly_data_error, auc_score

# %%
def process_data_set(data):
    normal_data, anomaly_data = split_anomaly_normal_data(data)
    selection_technics = [validate_classifier_by_random_points, kernel_metric, support_vectors_metric, combinatorial_dimension_metric]
    normal_train, normal_validate, normal_test = split_data_set(normal_data, 3)
    anomaly_train, anomaly_validate, anomaly_test = split_data_set(anomaly_data, 3)
    results = {}
    all_gammas = np.logspace(-10, 10, 50)
    for technic in selection_technics:
        start = time.time()
        metrics = model_selection(normal_validate, all_gammas, technic)
        duration = time.time() - start
        best_index = np.argmin(metrics)
        best_score = metrics[best_index]
        all_best_gamma = metrics == best_score
        possible_results = all_gammas[all_best_gamma]
        best_gamma = np.max(possible_results)
        fn, fp, auc = validate_gamma(normal_train, normal_test, anomaly_test, best_gamma)
        results[str(technic).split()[1]] = {'false negative': fn, 'false positive': fp, 'auc': auc, 'time':duration}
    return results

# %%
size = 10000
results = {}
for k in range(1, 15):
    for n in range(2, 30, 3):
        data = generate_dataset(size, dim=n, centroid_count=k)
        tmp = process_data_set(data)
        print tmp
        results["k = {}, n = {}".format(k, n)] = tmp
        print "k = {}".format(k), "n = {}".format(n)
# Out:
# {'support_vectors_metric': {'false positive': 0.0030769230769230769, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.07076923,
#         0.07384615,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.04204575,  0.04199534,  0.04193939, ..., -0.4896169 ,
#        -0.4896169 , -0.4896169 ])), 'false negative': 0.10705762018411183, 'time': 6.552986145019531}, 'validate_classifier_by_random_points': {'false positive': 0.0061538461538461538, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.31384615,
#         0.32615385,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.1868583 ,  0.18683864,  0.18682452, ..., -1.3298344 ,
#        -1.3298344 , -1.3298344 ])), 'false negative': 0.10944425502898057, 'time': 26.667667865753174}, 'kernel_metric': {'false positive': 0.0030769230769230769, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.00615385,
#         0.00615385,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          9.99659052e-01,   1.00000000e+00,   1.00000000e+00]), array([ 0.00134653,  0.00125706,  0.00120802, ..., -0.02058776,
#        -0.02059113, -0.02059165])), 'false negative': 0.4971019434026594, 'time': 22.907690048217773}, 'combinatorial_dimension_metric': {'false positive': 0.0030769230769230769, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.00615385,
#         0.00615385,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          9.99659052e-01,   1.00000000e+00,   1.00000000e+00]), array([ 0.00134653,  0.00125706,  0.00120802, ..., -0.02058776,
#        -0.02059113, -0.02059165])), 'false negative': 0.4971019434026594, 'time': 8.683825969696045}}
# k = 1 n = 2
# {'support_vectors_metric': {'false positive': 0.0, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.00307692,
#         0.00615385,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.01545903,  0.01495223,  0.01466028, ..., -0.05635064,
#        -0.05810722, -0.05810722])), 'false negative': 0.13262870780770541, 'time': 8.792829990386963}, 'validate_classifier_by_random_points': {'false positive': 0.0, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         0.00307692,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.00399406,  0.00385081,  0.00373988, ..., -0.01309621,
#        -0.01353946, -0.01354354])), 'false negative': 0.27821343334469828, 'time': 41.037715911865234}, 'kernel_metric': {'false positive': 0.0, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.00307692,
#         0.00615385,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.01545903,  0.01495223,  0.01466028, ..., -0.05635064,
#        -0.05810722, -0.05810722])), 'false negative': 0.13262870780770541, 'time': 24.532894134521484}, 'combinatorial_dimension_metric': {'false positive': 0.0, 'auc': (array([ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         0.00307692,  1.        ]), array([  3.40947835e-04,   6.81895670e-04,   1.02284350e-03, ...,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00]), array([ 0.00399406,  0.00385081,  0.00373988, ..., -0.01309621,
#        -0.01353946, -0.01354354])), 'false negative': 0.27821343334469828, 'time': 12.016064167022705}}
# k = 1 n = 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-03b9e85e20b3> in <module>()
#       4     for n in range(2, 30, 3):
#       5         data = generate_dataset(size, dim=n, centroid_count=k)
# ----> 6         tmp = process_data_set(data)
#       7         print tmp
#       8         results["k = {}, n = {}".format(k, n)] = tmp
#
# <ipython-input-37-3e94a20a580d> in process_data_set(data)
#       8     for technic in selection_technics:
#       9         start = time.time()
# ---> 10         metrics = model_selection(normal_validate, all_gammas, technic)
#      11         duration = time.time() - start
#      12         best_index = np.argmin(metrics)
#
# <ipython-input-15-afb5ab228e4e> in model_selection(data, all_gammas, selection_technic)
#       4     for index, gamma in enumerate(all_gammas):
#       5         clf = SVDD(C = 1.0 / 100, gamma=gamma, kernel='rbf')
# ----> 6         metrics[index] = selection_technic(clf, data)
#       7     return metrics
#
# <ipython-input-6-3c9175c21e75> in validate_classifier_by_random_points(clf, train_x, size)
#       5     negative_points *= np.std(train_x)
#       6     error = mean(clf.predict(positive_points) == -1)
# ----> 7     error += mean(clf.predict(negative_points) == 1)
#       8     return error
#
# /usr/local/lib/python2.7/dist-packages/sklearn/svm/base.pyc in predict(self, X)
#     286         X = self._validate_for_predict(X)
#     287         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 288         return predict(X)
#     289
#     290     def _dense_predict(self, X):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/svm/base.pyc in _dense_predict(self, X)
#     309             self.probA_, self.probB_, svm_type=svm_type, kernel=kernel,
#     310             degree=self.degree, coef0=self.coef0, gamma=self._gamma,
# --> 311             cache_size=self.cache_size)
#     312
#     313     def _sparse_predict(self, X):
#
# KeyboardInterrupt:

# %%
normal_data = np.random.randn(1000, 2)
anomaly_data = np.random.randn(10, 2) - 0.5
anomaly_data *= 50
labels = ['Target'] * 1000 + ['Outlier'] * 10
data = np.concatenate([normal_data, anomaly_data], axis=0)

data = pd.DataFrame(data)

# %%
data['labels'] = labels

# %%
data
# Out:
#               0           1   labels
# 0     -0.374272   -0.037361   Target
# 1     -0.045418    0.310972   Target
# 2     -1.387510   -0.151845   Target
# 3      0.802772   -0.787596   Target
# 4     -1.602887   -0.754612   Target
# 5     -1.073942   -0.489661   Target
# 6     -0.085912    0.758856   Target
# 7     -0.562779   -1.472338   Target
# 8     -1.589580   -1.984523   Target
# 9     -1.157671   -0.025991   Target
# 10    -1.011127    1.666395   Target
# 11     0.009725    0.151222   Target
# 12     0.095409    0.861399   Target
# 13     1.213393   -0.969341   Target
# 14    -1.820768   -0.157490   Target
# 15     0.085746    0.915457   Target
# 16     1.749502    0.817712   Target
# 17     0.502902    0.181273   Target
# 18     0.138355    1.031166   Target
# 19     0.880731    1.419543   Target
# 20     0.134332   -1.847855   Target
# 21     2.708720    2.086028   Target
# 22    -0.247947   -1.589701   Target
# 23    -1.707164    0.697061   Target
# 24    -2.167540   -1.198563   Target
# 25    -0.132924    0.163325   Target
# 26     0.701793    0.608479   Target
# 27    -0.314846   -1.263446   Target
# 28    -1.297255   -0.840236   Target
# 29     0.017009    0.612348   Target
# ...         ...         ...      ...
# 980   -0.404914   -0.906261   Target
# 981   -0.717719   -0.893278   Target
# 982    1.636878    0.122672   Target
# 983    2.128989   -0.627834   Target
# 984   -0.034755   -1.309578   Target
# 985   -0.473103   -2.560712   Target
# 986    0.449759   -0.203435   Target
# 987   -0.433568   -0.443784   Target
# 988    0.862099    1.478463   Target
# 989    0.661245    0.547258   Target
# 990   -1.041944    0.578806   Target
# 991   -0.183138    1.378789   Target
# 992   -1.794542    2.328204   Target
# 993   -0.552402   -0.316464   Target
# 994    0.808361    1.003490   Target
# 995   -0.652048    0.050744   Target
# 996   -0.836141    1.427463   Target
# 997   -1.432878    1.632823   Target
# 998    1.419430   -0.432256   Target
# 999   -0.843463   -0.060642   Target
# 1000  26.755386  -37.856541  Outlier
# 1001 -25.365986 -109.670737  Outlier
# 1002 -94.855831  -30.650366  Outlier
# 1003 -83.286023   27.159175  Outlier
# 1004 -23.751817  -46.825977  Outlier
# 1005  40.327348   46.192510  Outlier
# 1006 -57.477716  -57.062487  Outlier
# 1007 -35.899088  -31.116633  Outlier
# 1008  -9.478927  -52.308263  Outlier
# 1009 -90.554100  -64.244107  Outlier
#
# [1010 rows x 3 columns]

# %%
results
# Out:
# {'k = 1, n = 11': {'kernel_metric': {'auc': 0.99981116735293352,
#    'false negative': 0.11524036822366178,
#    'false positive': 0.0,
#    'time': 10.858461856842041},
#   'support_vectors_metric': {'auc': 0.96396863279918177,
#    'false negative': 0.38765768837367881,
#    'false positive': 0.0,
#    'time': 0.3508949279785156},
#   'validate_classifier_by_random_points': {'auc': 0.51261506989430616,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.917889833450317}},
#  'k = 1, n = 14': {'kernel_metric': {'auc': 0.99912717354244795,
#    'false negative': 0.200818274803955,
#    'false positive': 0.0,
#    'time': 11.046540975570679},
#   'support_vectors_metric': {'auc': 0.85313645781426217,
#    'false negative': 0.45414251619502216,
#    'false positive': 0.027692307692307693,
#    'time': 0.39176297187805176},
#   'validate_classifier_by_random_points': {'auc': 0.99936741063232715,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.152853965759277}},
#  'k = 1, n = 17': {'kernel_metric': {'auc': 0.97084214115240386,
#    'false negative': 0.10569382884418684,
#    'false positive': 0.046153846153846156,
#    'time': 11.608175039291382},
#   'support_vectors_metric': {'auc': 0.70739646987857008,
#    'false negative': 0.17933856120013639,
#    'false positive': 0.81230769230769229,
#    'time': 0.44220709800720215},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 16.498106956481934}},
#  'k = 1, n = 2': {'kernel_metric': {'auc': 1.0,
#    'false negative': 0.11660415956358677,
#    'false positive': 0.0,
#    'time': 9.438950061798096},
#   'support_vectors_metric': {'auc': 0.99999580371895402,
#    'false negative': 0.47869076031367203,
#    'false positive': 0.0,
#    'time': 0.20470404624938965},
#   'validate_classifier_by_random_points': {'auc': 0.99999580371895402,
#    'false negative': 0.46982611660415957,
#    'false positive': 0.0,
#    'time': 1.4671320915222168}},
#  'k = 1, n = 20': {'kernel_metric': {'auc': 0.95501271997692039,
#    'false negative': 0.12580975110808046,
#    'false positive': 0.080000000000000002,
#    'time': 12.445274114608765},
#   'support_vectors_metric': {'auc': 0.55999265650816965,
#    'false negative': 0.22843504943743606,
#    'false positive': 0.95999999999999996,
#    'time': 0.5149798393249512},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.44123601913452}},
#  'k = 1, n = 23': {'kernel_metric': {'auc': 0.92858034566865122,
#    'false negative': 0.18786225707466758,
#    'false positive': 0.070769230769230765,
#    'time': 13.099777936935425},
#   'support_vectors_metric': {'auc': 0.31841590390516405,
#    'false negative': 0.093760654619843162,
#    'false positive': 1.0,
#    'time': 0.538273811340332},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 20.221033096313477}},
#  'k = 1, n = 26': {'kernel_metric': {'auc': 0.32912796034514413,
#    'false negative': 0.11012615069894306,
#    'false positive': 1.0,
#    'time': 13.410091876983643},
#   'support_vectors_metric': {'auc': 0.17118623619816936,
#    'false negative': 0.14694851687691785,
#    'false positive': 1.0,
#    'time': 0.6243479251861572},
#   'validate_classifier_by_random_points': {'auc': 0.32912796034514413,
#    'false negative': 0.11012615069894306,
#    'false positive': 1.0,
#    'time': 27.745118141174316}},
#  'k = 1, n = 29': {'kernel_metric': {'auc': 0.3095942720763723,
#    'false negative': 0.11217183770883055,
#    'false positive': 1.0,
#    'time': 14.053325891494751},
#   'support_vectors_metric': {'auc': 0.17394214377507933,
#    'false negative': 0.15990453460620524,
#    'false positive': 1.0,
#    'time': 0.6539599895477295},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.791198015213013}},
#  'k = 1, n = 5': {'kernel_metric': {'auc': 1.0,
#    'false negative': 0.27616774633481078,
#    'false positive': 0.0,
#    'time': 9.489216804504395},
#   'support_vectors_metric': {'auc': 0.99989928925489791,
#    'false negative': 0.81111489942038872,
#    'false positive': 0.0,
#    'time': 0.25733113288879395},
#   'validate_classifier_by_random_points': {'auc': 0.99992236880065044,
#    'false negative': 0.10126150698943062,
#    'false positive': 0.0,
#    'time': 2.5716021060943604}},
#  'k = 1, n = 8': {'kernel_metric': {'auc': 1.0,
#    'false negative': 0.10501193317422435,
#    'false positive': 0.0,
#    'time': 9.978332996368408},
#   'support_vectors_metric': {'auc': 0.99805082745416873,
#    'false negative': 0.074326628025912042,
#    'false positive': 0.0061538461538461538,
#    'time': 0.3072972297668457},
#   'validate_classifier_by_random_points': {'auc': 0.97749744289123763,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 4.031759023666382}},
#  'k = 10, n = 11': {'kernel_metric': {'auc': 0.99919221589865981,
#    'false negative': 0.036481418342993524,
#    'false positive': 0.0030769230769230769,
#    'time': 10.545966863632202},
#   'support_vectors_metric': {'auc': 0.97964698785701165,
#    'false negative': 0.61166041595635867,
#    'false positive': 0.0,
#    'time': 0.35213494300842285},
#   'validate_classifier_by_random_points': {'auc': 0.99857536258490909,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.556922912597656}},
#  'k = 10, n = 14': {'kernel_metric': {'auc': 0.99669857588712019,
#    'false negative': 0.29867030344357315,
#    'false positive': 0.0,
#    'time': 11.062740087509155},
#   'support_vectors_metric': {'auc': 0.8548810616591046,
#    'false negative': 0.31537674735765425,
#    'false positive': 0.040000000000000001,
#    'time': 0.4010050296783447},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 10.325927972793579}},
#  'k = 10, n = 17': {'kernel_metric': {'auc': 0.98637572451414934,
#    'false negative': 0.054892601431980909,
#    'false positive': 0.027692307692307693,
#    'time': 11.6873300075531},
#   'support_vectors_metric': {'auc': 0.79428781242623725,
#    'false negative': 0.17013296965564267,
#    'false positive': 0.59076923076923082,
#    'time': 0.4785799980163574},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 14.593029975891113}},
#  'k = 10, n = 2': {'kernel_metric': {'auc': 0.99361430931836658,
#    'false negative': 0.99181725196045001,
#    'false positive': 0.0030769230769230769,
#    'time': 9.391369104385376},
#   'support_vectors_metric': {'auc': 0.99465288887723258,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.19637608528137207},
#   'validate_classifier_by_random_points': {'auc': 0.99465288887723258,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.514350175857544}},
#  'k = 10, n = 20': {'kernel_metric': {'auc': 0.95200398646699369,
#    'false negative': 0.15547221275144904,
#    'false positive': 0.040000000000000001,
#    'time': 16.3785400390625},
#   'support_vectors_metric': {'auc': 0.62288232054341841,
#    'false negative': 0.2052505966587112,
#    'false positive': 0.94153846153846155,
#    'time': 0.504331111907959},
#   'validate_classifier_by_random_points': {'auc': 0.99205591544493699,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 20.717514991760254}},
#  'k = 10, n = 23': {'kernel_metric': {'auc': 0.94910015998321484,
#    'false negative': 0.14933515172178657,
#    'false positive': 0.058461538461538461,
#    'time': 13.240700960159302},
#   'support_vectors_metric': {'auc': 0.45427574811823024,
#    'false negative': 0.17592908285032391,
#    'false positive': 1.0,
#    'time': 0.5398769378662109},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.43940782546997}},
#  'k = 10, n = 26': {'kernel_metric': {'auc': 0.87602192556846503,
#    'false negative': 0.34776679168087282,
#    'false positive': 0.049230769230769231,
#    'time': 14.126374006271362},
#   'support_vectors_metric': {'auc': 0.21156390149230245,
#    'false negative': 0.097511080804636885,
#    'false positive': 1.0,
#    'time': 0.7558410167694092},
#   'validate_classifier_by_random_points': {'auc': 0.87602192556846503,
#    'false negative': 0.34776679168087282,
#    'false positive': 0.049230769230769231,
#    'time': 27.962546825408936}},
#  'k = 10, n = 29': {'kernel_metric': {'auc': 0.30648272968082041,
#    'false negative': 0.079440845550630759,
#    'false positive': 1.0,
#    'time': 14.242604970932007},
#   'support_vectors_metric': {'auc': 0.13170132969655643,
#    'false negative': 0.078758949880668255,
#    'false positive': 1.0,
#    'time': 0.6816649436950684},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 33.77012896537781}},
#  'k = 10, n = 5': {'kernel_metric': {'auc': 0.99984159039051645,
#    'false negative': 0.47869076031367203,
#    'false positive': 0.0,
#    'time': 9.425640106201172},
#   'support_vectors_metric': {'auc': 0.99555928558315199,
#    'false negative': 0.78997613365155128,
#    'false positive': 0.0,
#    'time': 0.26076316833496094},
#   'validate_classifier_by_random_points': {'auc': 0.99803194418946217,
#    'false negative': 0.019774974428912375,
#    'false positive': 0.015384615384615385,
#    'time': 3.872385025024414}},
#  'k = 10, n = 8': {'kernel_metric': {'auc': 0.99991397623855849,
#    'false negative': 0.23116263211728605,
#    'false positive': 0.0,
#    'time': 10.512148141860962},
#   'support_vectors_metric': {'auc': 0.99044087177738738,
#    'false negative': 0.87794067507671325,
#    'false positive': 0.0,
#    'time': 0.3116300106048584},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 6.1016480922698975}},
#  'k = 11, n = 11': {'kernel_metric': {'auc': 0.99933593852448266,
#    'false negative': 0.15683600409137402,
#    'false positive': 0.0,
#    'time': 10.789723873138428},
#   'support_vectors_metric': {'auc': 0.95924991476304133,
#    'false negative': 0.057279236276849645,
#    'false positive': 0.19692307692307692,
#    'time': 0.3818371295928955},
#   'validate_classifier_by_random_points': {'auc': 0.96903144588108792,
#    'false negative': 0.11217183770883055,
#    'false positive': 0.030769230769230771,
#    'time': 8.376981019973755}},
#  'k = 11, n = 14': {'kernel_metric': {'auc': 0.99903170814865316,
#    'false negative': 0.1275144902829867,
#    'false positive': 0.0,
#    'time': 14.488221883773804},
#   'support_vectors_metric': {'auc': 0.90411287996013534,
#    'false negative': 0.045346062052505964,
#    'false positive': 0.72307692307692306,
#    'time': 0.49377894401550293},
#   'validate_classifier_by_random_points': {'auc': 0.99914920401793905,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.003190040588379}},
#  'k = 11, n = 17': {'kernel_metric': {'auc': 0.96912481313435972,
#    'false negative': 0.12819638595294919,
#    'false positive': 0.030769230769230771,
#    'time': 11.99818205833435},
#   'support_vectors_metric': {'auc': 0.71177214193920646,
#    'false negative': 0.18990794408455505,
#    'false positive': 0.78769230769230769,
#    'time': 0.4550158977508545},
#   'validate_classifier_by_random_points': {'auc': 0.99664035248760774,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 19.183459043502808}},
#  'k = 11, n = 2': {'kernel_metric': {'auc': 0.9822046211545018,
#    'false negative': 0.54006137061029658,
#    'false positive': 0.0030769230769230769,
#    'time': 10.269829988479614},
#   'support_vectors_metric': {'auc': 0.99705735791654648,
#    'false negative': 0.064439140811455853,
#    'false positive': 0.012307692307692308,
#    'time': 0.19599294662475586},
#   'validate_classifier_by_random_points': {'auc': 0.80061160796244335,
#    'false negative': 0.9901125127855438,
#    'false positive': 0.0,
#    'time': 1.6446797847747803}},
#  'k = 11, n = 20': {'kernel_metric': {'auc': 0.95973353615358392,
#    'false negative': 0.092396863279918168,
#    'false positive': 0.10153846153846154,
#    'time': 14.196555852890015},
#   'support_vectors_metric': {'auc': 0.61364106061003432,
#    'false negative': 0.087623593590180696,
#    'false positive': 1.0,
#    'time': 0.5275299549102783},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 24.548799991607666}},
#  'k = 11, n = 23': {'kernel_metric': {'auc': 0.94613863463505465,
#    'false negative': 0.14490282986703035,
#    'false positive': 0.08615384615384615,
#    'time': 13.158137083053589},
#   'support_vectors_metric': {'auc': 0.40926119226835211,
#    'false negative': 0.05318786225707467,
#    'false positive': 1.0,
#    'time': 0.5603179931640625},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 26.94179606437683}},
#  'k = 11, n = 26': {'kernel_metric': {'auc': 0.83340554433633196,
#    'false negative': 0.34844868735083534,
#    'false positive': 0.067692307692307691,
#    'time': 13.408556938171387},
#   'support_vectors_metric': {'auc': 0.22885257940150538,
#    'false negative': 0.2400272758267985,
#    'false positive': 1.0,
#    'time': 0.6296091079711914},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 28.851624965667725}},
#  'k = 11, n = 29': {'kernel_metric': {'auc': 0.25912455086679431,
#    'false negative': 0.094783498124786911,
#    'false positive': 1.0,
#    'time': 14.799448013305664},
#   'support_vectors_metric': {'auc': 0.11533898082824096,
#    'false negative': 0.087282645755199451,
#    'false positive': 1.0,
#    'time': 0.6614699363708496},
#   'validate_classifier_by_random_points': {'auc': 0.76886674185003545,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 31.736738920211792}},
#  'k = 11, n = 5': {'kernel_metric': {'auc': 0.99677410894594665,
#    'false negative': 0.46164336856460964,
#    'false positive': 0.0030769230769230769,
#    'time': 12.100077867507935},
#   'support_vectors_metric': {'auc': 0.99536101130373211,
#    'false negative': 0.99727241732015004,
#    'false positive': 0.0,
#    'time': 0.30457592010498047},
#   'validate_classifier_by_random_points': {'auc': 0.99547640903249501,
#    'false negative': 0.99727241732015004,
#    'false positive': 0.0,
#    'time': 4.944345951080322}},
#  'k = 11, n = 8': {'kernel_metric': {'auc': 0.99992027066012745,
#    'false negative': 0.19604500511421752,
#    'false positive': 0.0,
#    'time': 10.318520069122314},
#   'support_vectors_metric': {'auc': 0.98988486453880253,
#    'false negative': 0.47391749062393451,
#    'false positive': 0.0,
#    'time': 0.3025200366973877},
#   'validate_classifier_by_random_points': {'auc': 0.99992027066012745,
#    'false negative': 0.19604500511421752,
#    'false positive': 0.0,
#    'time': 6.59081506729126}},
#  'k = 12, n = 11': {'kernel_metric': {'auc': 0.99993703431629766,
#    'false negative': 0.056616643929058665,
#    'false positive': 0.0,
#    'time': 11.128693103790283},
#   'support_vectors_metric': {'auc': 0.96487144506244094,
#    'false negative': 0.97783083219645295,
#    'false positive': 0.0,
#    'time': 0.3627631664276123},
#   'validate_classifier_by_random_points': {'auc': 0.99993703431629766,
#    'false negative': 0.056616643929058665,
#    'false positive': 0.0,
#    'time': 8.591455221176147}},
#  'k = 12, n = 14': {'kernel_metric': {'auc': 0.99939028229614868,
#    'false negative': 0.17871759890859482,
#    'false positive': 0.0,
#    'time': 11.510854959487915},
#   'support_vectors_metric': {'auc': 0.91112918459439607,
#    'false negative': 0.2834242837653479,
#    'false positive': 0.030769230769230771,
#    'time': 0.39130187034606934},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.569068908691406}},
#  'k = 12, n = 17': {'kernel_metric': {'auc': 0.98308531850141656,
#    'false negative': 0.085948158253751711,
#    'false positive': 0.036923076923076927,
#    'time': 15.552058935165405},
#   'support_vectors_metric': {'auc': 0.80703536572567947,
#    'false negative': 0.19781718963165076,
#    'false positive': 0.40307692307692305,
#    'time': 0.44330692291259766},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 32.719868898391724}},
#  'k = 12, n = 2': {'kernel_metric': {'auc': 0.93477804596494907,
#    'false negative': 0.92257844474761252,
#    'false positive': 0.0061538461538461538,
#    'time': 9.253622055053711},
#   'support_vectors_metric': {'auc': 0.98270227725889381,
#    'false negative': 0.48703956343792632,
#    'false positive': 0.018461538461538463,
#    'time': 0.20455098152160645},
#   'validate_classifier_by_random_points': {'auc': 0.52072305593451573,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.5094850063323975}},
#  'k = 12, n = 20': {'kernel_metric': {'auc': 0.95691153321439826,
#    'false negative': 0.11289222373806275,
#    'false positive': 0.058461538461538461,
#    'time': 13.95920991897583},
#   'support_vectors_metric': {'auc': 0.56448945324797983,
#    'false negative': 0.09345156889495225,
#    'false positive': 1.0,
#    'time': 0.5048530101776123},
#   'validate_classifier_by_random_points': {'auc': 0.56448945324797983,
#    'false negative': 0.09345156889495225,
#    'false positive': 1.0,
#    'time': 22.18274998664856}},
#  'k = 12, n = 23': {'kernel_metric': {'auc': 0.97103893378108919,
#    'false negative': 0.068553888130968618,
#    'false positive': 0.098461538461538461,
#    'time': 13.320806980133057},
#   'support_vectors_metric': {'auc': 0.47173155630181551,
#    'false negative': 0.090040927694406553,
#    'false positive': 1.0,
#    'time': 0.5678870677947998},
#   'validate_classifier_by_random_points': {'auc': 0.47655472767341794,
#    'false negative': 0.034447476125511599,
#    'false positive': 1.0,
#    'time': 24.713456869125366}},
#  'k = 12, n = 26': {'kernel_metric': {'auc': 0.87772798824640574,
#    'false negative': 0.31616643929058663,
#    'false positive': 0.040000000000000001,
#    'time': 13.380234956741333},
#   'support_vectors_metric': {'auc': 0.2252062126141253,
#    'false negative': 0.093110504774897684,
#    'false positive': 1.0,
#    'time': 0.6177680492401123},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 26.358759880065918}},
#  'k = 12, n = 29': {'kernel_metric': {'auc': 0.33754119005142197,
#    'false negative': 0.052864938608458388,
#    'false positive': 1.0,
#    'time': 13.860124111175537},
#   'support_vectors_metric': {'auc': 0.14228040717808793,
#    'false negative': 0.067871759890859487,
#    'false positive': 1.0,
#    'time': 0.64406418800354},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 31.484757900238037}},
#  'k = 12, n = 5': {'kernel_metric': {'auc': 0.99997586315458054,
#    'false negative': 0.59072305593451568,
#    'false positive': 0.0,
#    'time': 9.771888971328735},
#   'support_vectors_metric': {'auc': 0.99335187322909013,
#    'false negative': 0.75272851296043652,
#    'false positive': 0.0,
#    'time': 0.2669649124145508},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.503265142440796}},
#  'k = 12, n = 8': {'kernel_metric': {'auc': 0.99950676881099798,
#    'false negative': 0.43724420190995905,
#    'false positive': 0.0,
#    'time': 10.333392858505249},
#   'support_vectors_metric': {'auc': 0.98645083429530889,
#    'false negative': 0.28922237380627558,
#    'false positive': 0.0030769230769230769,
#    'time': 0.3084390163421631},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 6.506143093109131}},
#  'k = 13, n = 11': {'kernel_metric': {'auc': 0.99944113244215682,
#    'false negative': 0.051212017753499491,
#    'false positive': 0.0,
#    'time': 10.625090837478638},
#   'support_vectors_metric': {'auc': 0.97034850434645581,
#    'false negative': 0.75691362239672244,
#    'false positive': 0.0,
#    'time': 0.3235280513763428},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 9.141608953475952}},
#  'k = 13, n = 14': {'kernel_metric': {'auc': 0.99929301152926964,
#    'false negative': 0.25162171389552751,
#    'false positive': 0.0,
#    'time': 11.046962976455688},
#   'support_vectors_metric': {'auc': 0.8926512067652389,
#    'false negative': 0.27654489586889724,
#    'false positive': 0.055384615384615386,
#    'time': 0.4032759666442871},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.128253936767578}},
#  'k = 13, n = 17': {'kernel_metric': {'auc': 0.98376132573469555,
#    'false negative': 0.065892796176169346,
#    'false positive': 0.033846153846153845,
#    'time': 11.71398401260376},
#   'support_vectors_metric': {'auc': 0.81924311264017657,
#    'false negative': 0.14066234209627859,
#    'false positive': 0.62153846153846148,
#    'time': 0.44715189933776855},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.1548011302948}},
#  'k = 13, n = 2': {'kernel_metric': {'auc': 0.97746356067967521,
#    'false negative': 0.93479003072721067,
#    'false positive': 0.0,
#    'time': 9.009850025177002},
#   'support_vectors_metric': {'auc': 0.99197205662210797,
#    'false negative': 0.88289518607033113,
#    'false positive': 0.0030769230769230769,
#    'time': 0.19317889213562012},
#   'validate_classifier_by_random_points': {'auc': 0.99595556372613381,
#    'false negative': 0.38101741208603618,
#    'false positive': 0.0030769230769230769,
#    'time': 1.4923739433288574}},
#  'k = 13, n = 20': {'kernel_metric': {'auc': 0.94985214171284493,
#    'false negative': 0.12188460225332878,
#    'false positive': 0.076923076923076927,
#    'time': 12.180586099624634},
#   'support_vectors_metric': {'auc': 0.59410877957822306,
#    'false negative': 0.077500853533629219,
#    'false positive': 1.0,
#    'time': 0.5059709548950195},
#   'validate_classifier_by_random_points': {'auc': 0.98939307193318793,
#    'false negative': 0.99692727893479005,
#    'false positive': 0.0,
#    'time': 21.81504487991333}},
#  'k = 13, n = 23': {'kernel_metric': {'auc': 0.91869422486015184,
#    'false negative': 0.18163195629907819,
#    'false positive': 0.08615384615384615,
#    'time': 12.774125099182129},
#   'support_vectors_metric': {'auc': 0.37073824093284657,
#    'false negative': 0.13861386138613863,
#    'false positive': 1.0,
#    'time': 0.5418519973754883},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 24.064671993255615}},
#  'k = 13, n = 26': {'kernel_metric': {'auc': 0.84329962969771766,
#    'false negative': 0.33492659610788666,
#    'false positive': 0.058461538461538461,
#    'time': 13.258800029754639},
#   'support_vectors_metric': {'auc': 0.23651968379861857,
#    'false negative': 0.16421987026288837,
#    'false positive': 1.0,
#    'time': 0.5979571342468262},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 28.98059105873108}},
#  'k = 13, n = 29': {'kernel_metric': {'auc': 0.32246658087559421,
#    'false negative': 0.081256401502219189,
#    'false positive': 1.0,
#    'time': 13.813560962677002},
#   'support_vectors_metric': {'auc': 0.14493893951729389,
#    'false negative': 0.079549334243769199,
#    'false positive': 1.0,
#    'time': 0.6216490268707275},
#   'validate_classifier_by_random_points': {'auc': 0.7955752816660977,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 33.86501502990723}},
#  'k = 13, n = 5': {'kernel_metric': {'auc': 0.99971741471229347,
#    'false negative': 0.38648002731307612,
#    'false positive': 0.0,
#    'time': 9.504462003707886},
#   'support_vectors_metric': {'auc': 0.99551120098747281,
#    'false negative': 0.9730283373164903,
#    'false positive': 0.0,
#    'time': 0.2578589916229248},
#   'validate_classifier_by_random_points': {'auc': 0.9957790792341833,
#    'false negative': 0.11095937179924889,
#    'false positive': 0.0061538461538461538,
#    'time': 3.425034999847412}},
#  'k = 13, n = 8': {'kernel_metric': {'auc': 0.99971846521522179,
#    'false negative': 0.30385797200409698,
#    'false positive': 0.0,
#    'time': 10.039499998092651},
#   'support_vectors_metric': {'auc': 0.98784883262862111,
#    'false negative': 0.2092864458859679,
#    'false positive': 0.0061538461538461538,
#    'time': 0.29605889320373535},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.252532958984375}},
#  'k = 14, n = 11': {'kernel_metric': {'auc': 0.99950853242320825,
#    'false negative': 0.026962457337883959,
#    'false positive': 0.0030769230769230769,
#    'time': 10.507864952087402},
#   'support_vectors_metric': {'auc': 0.95971751115778414,
#    'false negative': 0.10068259385665529,
#    'false positive': 0.076923076923076927,
#    'time': 0.34607386589050293},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.513795137405396}},
#  'k = 14, n = 14': {'kernel_metric': {'auc': 0.9995851929640327,
#    'false negative': 0.12013651877133105,
#    'false positive': 0.0,
#    'time': 11.078080177307129},
#   'support_vectors_metric': {'auc': 0.91940981885009176,
#    'false negative': 0.61194539249146762,
#    'false positive': 0.0,
#    'time': 0.39437413215637207},
#   'validate_classifier_by_random_points': {'auc': 0.98779312155421373,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 12.162513971328735}},
#  'k = 14, n = 17': {'kernel_metric': {'auc': 0.96853452349698088,
#    'false negative': 0.11331058020477816,
#    'false positive': 0.049230769230769231,
#    'time': 12.05676794052124},
#   'support_vectors_metric': {'auc': 0.7623701758991861,
#    'false negative': 0.30204778156996587,
#    'false positive': 0.25230769230769229,
#    'time': 0.5414438247680664},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.770574808120728}},
#  'k = 14, n = 2': {'kernel_metric': {'auc': 0.98331530585455529,
#    'false negative': 0.57986348122866893,
#    'false positive': 0.0061538461538461538,
#    'time': 9.07573914527893},
#   'support_vectors_metric': {'auc': 0.99616592281438687,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.19137310981750488},
#   'validate_classifier_by_random_points': {'auc': 0.99512627986348112,
#    'false negative': 0.012286689419795221,
#    'false positive': 0.027692307692307693,
#    'time': 1.4447321891784668}},
#  'k = 14, n = 20': {'kernel_metric': {'auc': 0.96097453399842481,
#    'false negative': 0.12354948805460751,
#    'false positive': 0.058461538461538461,
#    'time': 12.36500096321106},
#   'support_vectors_metric': {'auc': 0.56767865581517452,
#    'false negative': 0.12559726962457338,
#    'false positive': 1.0,
#    'time': 0.49781298637390137},
#   'validate_classifier_by_random_points': {'auc': 0.98858388028353905,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.68680500984192}},
#  'k = 14, n = 23': {'kernel_metric': {'auc': 0.89332423208191125,
#    'false negative': 0.22798634812286689,
#    'false positive': 0.089230769230769225,
#    'time': 13.329219818115234},
#   'support_vectors_metric': {'auc': 0.3465003938041481,
#    'false negative': 0.091126279863481235,
#    'false positive': 1.0,
#    'time': 0.5395088195800781},
#   'validate_classifier_by_random_points': {'auc': 0.3465003938041481,
#    'false negative': 0.091126279863481235,
#    'false positive': 1.0,
#    'time': 23.81962513923645}},
#  'k = 14, n = 26': {'kernel_metric': {'auc': 0.84400840115515885,
#    'false negative': 0.3778156996587031,
#    'false positive': 0.046153846153846156,
#    'time': 23.98667001724243},
#   'support_vectors_metric': {'auc': 0.19974271462326071,
#    'false negative': 0.15358361774744028,
#    'false positive': 1.0,
#    'time': 1.4357399940490723},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 39.37586808204651}},
#  'k = 14, n = 29': {'kernel_metric': {'auc': 0.25878708322394328,
#    'false negative': 0.11194539249146758,
#    'false positive': 1.0,
#    'time': 18.0631000995636},
#   'support_vectors_metric': {'auc': 0.12064688894723025,
#    'false negative': 0.10819112627986348,
#    'false positive': 1.0,
#    'time': 0.7234139442443848},
#   'validate_classifier_by_random_points': {'auc': 0.13722866894197952,
#    'false negative': 0.11467576791808874,
#    'false positive': 1.0,
#    'time': 39.57191801071167}},
#  'k = 14, n = 5': {'kernel_metric': {'auc': 0.99840378051982148,
#    'false negative': 0.63378839590443681,
#    'false positive': 0.0,
#    'time': 9.417693853378296},
#   'support_vectors_metric': {'auc': 0.98983880283538983,
#    'false negative': 0.88054607508532423,
#    'false positive': 0.0,
#    'time': 0.2531709671020508},
#   'validate_classifier_by_random_points': {'auc': 0.99025571016014702,
#    'false negative': 0.88771331058020475,
#    'false positive': 0.0,
#    'time': 3.503933906555176}},
#  'k = 14, n = 8': {'kernel_metric': {'auc': 0.99954528747702809,
#    'false negative': 0.33515358361774744,
#    'false positive': 0.0,
#    'time': 10.136775970458984},
#   'support_vectors_metric': {'auc': 0.98129797847203992,
#    'false negative': 0.92730375426621159,
#    'false positive': 0.0,
#    'time': 0.3019859790802002},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.878350019454956}},
#  'k = 2, n = 11': {'kernel_metric': {'auc': 0.99951952582024184,
#    'false negative': 0.32969655642686668,
#    'false positive': 0.0,
#    'time': 10.465626001358032},
#   'support_vectors_metric': {'auc': 0.96253245561121448,
#    'false negative': 0.51414933515172179,
#    'false positive': 0.0,
#    'time': 0.3405799865722656},
#   'validate_classifier_by_random_points': {'auc': 0.56358677122400269,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 10.190932989120483}},
#  'k = 2, n = 14': {'kernel_metric': {'auc': 0.99797424532508072,
#    'false negative': 0.34844868735083534,
#    'false positive': 0.0,
#    'time': 11.809922933578491},
#   'support_vectors_metric': {'auc': 0.88326785386451268,
#    'false negative': 0.35799522673031026,
#    'false positive': 0.030769230769230771,
#    'time': 0.40834784507751465},
#   'validate_classifier_by_random_points': {'auc': 0.99881664874504983,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 10.335423946380615}},
#  'k = 2, n = 17': {'kernel_metric': {'auc': 0.95142804689344063,
#    'false negative': 0.22195704057279236,
#    'false positive': 0.012307692307692308,
#    'time': 12.168361186981201},
#   'support_vectors_metric': {'auc': 0.74652259435075663,
#    'false negative': 0.16774633481077394,
#    'false positive': 0.73538461538461541,
#    'time': 0.4798860549926758},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.26773500442505}},
#  'k = 2, n = 2': {'kernel_metric': {'auc': 0.52113876576883733,
#    'false negative': 0.99931810433003754,
#    'false positive': 0.0,
#    'time': 9.228447198867798},
#   'support_vectors_metric': {'auc': 0.98320963046500032,
#    'false negative': 0.98670303443573137,
#    'false positive': 0.0,
#    'time': 0.19606804847717285},
#   'validate_classifier_by_random_points': {'auc': 0.97911983005061753,
#    'false negative': 0.98090692124105017,
#    'false positive': 0.0,
#    'time': 1.5172560214996338}},
#  'k = 2, n = 20': {'kernel_metric': {'auc': 0.9250900889087047,
#    'false negative': 0.27139447664507332,
#    'false positive': 0.043076923076923075,
#    'time': 12.842610120773315},
#   'support_vectors_metric': {'auc': 0.6027191901177581,
#    'false negative': 0.36720081827480394,
#    'false positive': 0.53846153846153844,
#    'time': 0.5086369514465332},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.765363931655884}},
#  'k = 2, n = 23': {'kernel_metric': {'auc': 0.85923155603346535,
#    'false negative': 0.28435049437436072,
#    'false positive': 0.10461538461538461,
#    'time': 13.186815977096558},
#   'support_vectors_metric': {'auc': 0.36317448661124074,
#    'false negative': 0.29389703375383569,
#    'false positive': 0.99692307692307691,
#    'time': 0.5763428211212158},
#   'validate_classifier_by_random_points': {'auc': 0.50068189566996246,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.42736792564392}},
#  'k = 2, n = 26': {'kernel_metric': {'auc': 0.91551102835112386,
#    'false negative': 0.24105011933174225,
#    'false positive': 0.055384615384615386,
#    'time': 13.411845207214355},
#   'support_vectors_metric': {'auc': 0.26155000131133782,
#    'false negative': 0.075349471530855777,
#    'false positive': 1.0,
#    'time': 0.60135817527771},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 28.186951875686646}},
#  'k = 2, n = 29': {'kernel_metric': {'auc': 0.21205906265572136,
#    'false negative': 0.14251619502216162,
#    'false positive': 1.0,
#    'time': 13.862088918685913},
#   'support_vectors_metric': {'auc': 0.1016926748668992,
#    'false negative': 0.15751789976133651,
#    'false positive': 1.0,
#    'time': 0.6716289520263672},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 34.11913084983826}},
#  'k = 2, n = 5': {'kernel_metric': {'auc': 0.99827218127934125,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 9.628607034683228},
#   'support_vectors_metric': {'auc': 0.99385664454876865,
#    'false negative': 0.51960450051142171,
#    'false positive': 0.0,
#    'time': 0.26321911811828613},
#   'validate_classifier_by_random_points': {'auc': 0.99777282383487642,
#    'false negative': 0.87078077054210701,
#    'false positive': 0.0,
#    'time': 2.861375093460083}},
#  'k = 2, n = 8': {'kernel_metric': {'auc': 0.99945238532350711,
#    'false negative': 0.4851687691783157,
#    'false positive': 0.0,
#    'time': 9.93596887588501},
#   'support_vectors_metric': {'auc': 0.98196123685383829,
#    'false negative': 0.46573474258438458,
#    'false positive': 0.0,
#    'time': 0.3030869960784912},
#   'validate_classifier_by_random_points': {'auc': 0.99903065907839184,
#    'false negative': 0.17013296965564267,
#    'false positive': 0.0,
#    'time': 5.29292106628418}},
#  'k = 3, n = 11': {'kernel_metric': {'auc': 0.99999475464869259,
#    'false negative': 0.63245823389021483,
#    'false positive': 0.0,
#    'time': 11.020900964736938},
#   'support_vectors_metric': {'auc': 0.9614718455768575,
#    'false negative': 0.13365155131264916,
#    'false positive': 0.021538461538461538,
#    'time': 0.3742249011993408},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.37623405456543}},
#  'k = 3, n = 14': {'kernel_metric': {'auc': 0.99984473760130088,
#    'false negative': 0.52130923968632803,
#    'false positive': 0.0,
#    'time': 12.305277109146118},
#   'support_vectors_metric': {'auc': 0.95458574838049781,
#    'false negative': 0.12785543811796796,
#    'false positive': 0.076923076923076927,
#    'time': 0.4259629249572754},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 9.390965938568115}},
#  'k = 3, n = 17': {'kernel_metric': {'auc': 0.97809751108080467,
#    'false negative': 0.13910671667234914,
#    'false positive': 0.015384615384615385,
#    'time': 12.1495201587677},
#   'support_vectors_metric': {'auc': 0.8165176112670145,
#    'false negative': 0.091033071939993188,
#    'false positive': 0.84923076923076923,
#    'time': 0.48354506492614746},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.95765709877014}},
#  'k = 3, n = 2': {'kernel_metric': {'auc': 0.90298093314799754,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 9.230211973190308},
#   'support_vectors_metric': {'auc': 0.99632300873350976,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.20352888107299805},
#   'validate_classifier_by_random_points': {'auc': 0.99610480211912189,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.487851858139038}},
#  'k = 3, n = 20': {'kernel_metric': {'auc': 0.97902488919195363,
#    'false negative': 0.041254688032730989,
#    'false positive': 0.10153846153846154,
#    'time': 12.083808898925781},
#   'support_vectors_metric': {'auc': 0.64918565920952553,
#    'false negative': 0.040913740197749744,
#    'false positive': 1.0,
#    'time': 0.537121057510376},
#   'validate_classifier_by_random_points': {'auc': 0.65186498465734743,
#    'false negative': 0.063075349471530859,
#    'false positive': 1.0,
#    'time': 21.511898040771484}},
#  'k = 3, n = 23': {'kernel_metric': {'auc': 0.94208712528521599,
#    'false negative': 0.10637572451414934,
#    'false positive': 0.14153846153846153,
#    'time': 12.661972999572754},
#   'support_vectors_metric': {'auc': 0.4225644522541897,
#    'false negative': 0.089328332765086949,
#    'false positive': 1.0,
#    'time': 0.5496020317077637},
#   'validate_classifier_by_random_points': {'auc': 0.60614230638096989,
#    'false negative': 0.072621888851005803,
#    'false positive': 1.0,
#    'time': 21.688509941101074}},
#  'k = 3, n = 26': {'kernel_metric': {'auc': 0.86622360932623466,
#    'false negative': 0.31162632117286054,
#    'false positive': 0.061538461538461542,
#    'time': 13.255199909210205},
#   'support_vectors_metric': {'auc': 0.24091898554905714,
#    'false negative': 0.18956699624957382,
#    'false positive': 1.0,
#    'time': 0.6098079681396484},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.296168088912964}},
#  'k = 3, n = 29': {'kernel_metric': {'auc': 0.35164625350782869,
#    'false negative': 0.067507671326287072,
#    'false positive': 1.0,
#    'time': 13.790961980819702},
#   'support_vectors_metric': {'auc': 0.13838810354323478,
#    'false negative': 0.03954994885782475,
#    'false positive': 1.0,
#    'time': 0.6320819854736328},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.77836799621582}},
#  'k = 3, n = 5': {'kernel_metric': {'auc': 0.99999580371895413,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 9.496093988418579},
#   'support_vectors_metric': {'auc': 0.99916913635290727,
#    'false negative': 0.01943402659393113,
#    'false positive': 0.0092307692307692316,
#    'time': 0.2509169578552246},
#   'validate_classifier_by_random_points': {'auc': 1.0,
#    'false negative': 0.72178656665530172,
#    'false positive': 0.0,
#    'time': 2.4556210041046143}},
#  'k = 3, n = 8': {'kernel_metric': {'auc': 0.99984159039051645,
#    'false negative': 0.316399590862598,
#    'false positive': 0.0,
#    'time': 9.97838807106018},
#   'support_vectors_metric': {'auc': 0.98278790421988504,
#    'false negative': 0.39618138424821003,
#    'false positive': 0.0,
#    'time': 0.3061552047729492},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.347291946411133}},
#  'k = 4, n = 11': {'kernel_metric': {'auc': 0.9995950588790683,
#    'false negative': 0.25639277190589838,
#    'false positive': 0.0,
#    'time': 10.598385095596313},
#   'support_vectors_metric': {'auc': 0.95974087964541432,
#    'false negative': 0.63382202523013975,
#    'false positive': 0.0,
#    'time': 0.352586030960083},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.723129034042358}},
#  'k = 4, n = 14': {'kernel_metric': {'auc': 0.99998006766503189,
#    'false negative': 0.10671667234913058,
#    'false positive': 0.0,
#    'time': 11.060135126113892},
#   'support_vectors_metric': {'auc': 0.9633507304151695,
#    'false negative': 0.14967609955676781,
#    'false positive': 0.036923076923076927,
#    'time': 0.39303112030029297},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.037923097610474}},
#  'k = 4, n = 17': {'kernel_metric': {'auc': 0.94200110152377448,
#    'false negative': 0.1830889873849301,
#    'false positive': 0.058461538461538461,
#    'time': 11.514822959899902},
#   'support_vectors_metric': {'auc': 0.72130294526475913,
#    'false negative': 0.1680872826457552,
#    'false positive': 0.77230769230769236,
#    'time': 0.47086405754089355},
#   'validate_classifier_by_random_points': {'auc': 0.73451913241889388,
#    'false negative': 0.13262870780770541,
#    'false positive': 0.84307692307692306,
#    'time': 17.527074098587036}},
#  'k = 4, n = 2': {'kernel_metric': {'auc': 0.96263264182118602,
#    'false negative': 0.90419365837026933,
#    'false positive': 0.0030769230769230769,
#    'time': 8.85525107383728},
#   'support_vectors_metric': {'auc': 0.99129691311075552,
#    'false negative': 0.11353562904875554,
#    'false positive': 0.021538461538461538,
#    'time': 0.19517016410827637},
#   'validate_classifier_by_random_points': {'auc': 0.99428991056676019,
#    'false negative': 0.061029662461643368,
#    'false positive': 0.024615384615384615,
#    'time': 1.594313144683838}},
#  'k = 4, n = 20': {'kernel_metric': {'auc': 0.94848645388024855,
#    'false negative': 0.1026252983293556,
#    'false positive': 0.11384615384615385,
#    'time': 12.070293188095093},
#   'support_vectors_metric': {'auc': 0.54047260615279702,
#    'false negative': 0.1295601772928742,
#    'false positive': 1.0,
#    'time': 0.497528076171875},
#   'validate_classifier_by_random_points': {'auc': 0.98700726481156076,
#    'false negative': 0.99659052165018747,
#    'false positive': 0.0,
#    'time': 21.582524061203003}},
#  'k = 4, n = 23': {'kernel_metric': {'auc': 0.95173437540979311,
#    'false negative': 0.1131946812137743,
#    'false positive': 0.08615384615384615,
#    'time': 12.764110803604126},
#   'support_vectors_metric': {'auc': 0.44118964567651919,
#    'false negative': 0.083873167405386972,
#    'false positive': 1.0,
#    'time': 0.5263700485229492},
#   'validate_classifier_by_random_points': {'auc': 0.46716777256156738,
#    'false negative': 0.087282645755199451,
#    'false positive': 1.0,
#    'time': 25.752028942108154}},
#  'k = 4, n = 26': {'kernel_metric': {'auc': 0.94073802092895187,
#    'false negative': 0.18070235254006137,
#    'false positive': 0.049230769230769231,
#    'time': 13.218676090240479},
#   'support_vectors_metric': {'auc': 0.34641139290303968,
#    'false negative': 0.051824070917149676,
#    'false positive': 1.0,
#    'time': 0.5992732048034668},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 29.349202156066895}},
#  'k = 4, n = 29': {'kernel_metric': {'auc': 0.20101235280232893,
#    'false negative': 0.12990112512785543,
#    'false positive': 1.0,
#    'time': 13.733312845230103},
#   'support_vectors_metric': {'auc': 0.087636182433318471,
#    'false negative': 0.16331401295601772,
#    'false positive': 1.0,
#    'time': 0.6309070587158203},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.13875985145569}},
#  'k = 4, n = 5': {'kernel_metric': {'auc': 0.99717275564530927,
#    'false negative': 0.95704057279236276,
#    'false positive': 0.0,
#    'time': 9.432536125183105},
#   'support_vectors_metric': {'auc': 0.99955519420913208,
#    'false negative': 0.10705762018411183,
#    'false positive': 0.0,
#    'time': 0.2695920467376709},
#   'validate_classifier_by_random_points': {'auc': 0.99965695402449584,
#    'false negative': 0.068530514831230821,
#    'false positive': 0.0,
#    'time': 2.8654019832611084}},
#  'k = 4, n = 8': {'kernel_metric': {'auc': 0.99915340029898503,
#    'false negative': 0.76440504602795767,
#    'false positive': 0.0,
#    'time': 9.943475008010864},
#   'support_vectors_metric': {'auc': 0.98815809488840511,
#    'false negative': 0.54040231844527786,
#    'false positive': 0.0,
#    'time': 0.31049394607543945},
#   'validate_classifier_by_random_points': {'auc': 0.98815809488840511,
#    'false negative': 0.54040231844527786,
#    'false positive': 0.0,
#    'time': 4.670707941055298}},
#  'k = 5, n = 11': {'kernel_metric': {'auc': 0.99862466888719881,
#    'false negative': 0.3818615751789976,
#    'false positive': 0.0,
#    'time': 10.40089201927185},
#   'support_vectors_metric': {'auc': 0.93816570064780092,
#    'false negative': 0.96283668598704397,
#    'false positive': 0.0,
#    'time': 0.3574228286743164},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.937610149383545}},
#  'k = 5, n = 14': {'kernel_metric': {'auc': 0.99634189199821677,
#    'false negative': 0.42686668939652234,
#    'false positive': 0.0,
#    'time': 10.969815969467163},
#   'support_vectors_metric': {'auc': 0.86537071520365072,
#    'false negative': 0.67712240027275827,
#    'false positive': 0.0,
#    'time': 0.3997530937194824},
#   'validate_classifier_by_random_points': {'auc': 0.86537071520365072,
#    'false negative': 0.67712240027275827,
#    'false positive': 0.0,
#    'time': 10.606926918029785}},
#  'k = 5, n = 17': {'kernel_metric': {'auc': 0.98318025649767893,
#    'false negative': 0.10330719399931811,
#    'false positive': 0.027692307692307693,
#    'time': 11.574772834777832},
#   'support_vectors_metric': {'auc': 0.86918093839334876,
#    'false negative': 0.29935219911353561,
#    'false positive': 0.052307692307692305,
#    'time': 0.5156199932098389},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 16.709343910217285}},
#  'k = 5, n = 2': {'kernel_metric': {'auc': 0.57233706627501379,
#    'false negative': 0.98977156495056251,
#    'false positive': 0.0030769230769230769,
#    'time': 8.902943849563599},
#   'support_vectors_metric': {'auc': 0.98259907157281856,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.19286203384399414},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4661610126495361}},
#  'k = 5, n = 20': {'kernel_metric': {'auc': 0.92766975268168594,
#    'false negative': 0.22809410160245483,
#    'false positive': 0.036923076923076927,
#    'time': 12.067681789398193},
#   'support_vectors_metric': {'auc': 0.53753101313960505,
#    'false negative': 0.12274122059324924,
#    'false positive': 1.0,
#    'time': 0.5235328674316406},
#   'validate_classifier_by_random_points': {'auc': 0.53753101313960505,
#    'false negative': 0.12274122059324924,
#    'false positive': 1.0,
#    'time': 21.796454906463623}},
#  'k = 5, n = 23': {'kernel_metric': {'auc': 0.86596239083112592,
#    'false negative': 0.26934878963518583,
#    'false positive': 0.080000000000000002,
#    'time': 12.64424991607666},
#   'support_vectors_metric': {'auc': 0.36478795667339819,
#    'false negative': 0.33481077395158543,
#    'false positive': 1.0,
#    'time': 0.5541391372680664},
#   'validate_classifier_by_random_points': {'auc': 0.51001914553227201,
#    'false negative': 0.22638936242754859,
#    'false positive': 0.99692307692307691,
#    'time': 24.707522869110107}},
#  'k = 5, n = 26': {'kernel_metric': {'auc': 0.36391827742663063,
#    'false negative': 0.10705762018411183,
#    'false positive': 1.0,
#    'time': 13.443637132644653},
#   'support_vectors_metric': {'auc': 0.20268561986939077,
#    'false negative': 0.1745652915103989,
#    'false positive': 1.0,
#    'time': 0.5970261096954346},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.015249967575073}},
#  'k = 5, n = 29': {'kernel_metric': {'auc': 0.18643552151905374,
#    'false negative': 0.19229457892942381,
#    'false positive': 1.0,
#    'time': 13.803743124008179},
#   'support_vectors_metric': {'auc': 0.07248760785753626,
#    'false negative': 0.16365496079099898,
#    'false positive': 1.0,
#    'time': 0.6545062065124512},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 29.50060200691223}},
#  'k = 5, n = 5': {'kernel_metric': {'auc': 0.99186708279787039,
# ...
#    'false negative': 0.17701227830832197,
#    'false positive': 1.0,
#    'time': 32.83692908287048}},
#  'k = 6, n = 5': {'kernel_metric': {'auc': 0.99956763563857698,
#    'false negative': 0.92155525238744884,
#    'false positive': 0.0,
#    'time': 9.385833978652954},
#   'support_vectors_metric': {'auc': 0.99763773743309903,
#    'false negative': 0.17360163710777626,
#    'false positive': 0.0,
#    'time': 0.2506849765777588},
#   'validate_classifier_by_random_points': {'auc': 0.99979431209990566,
#    'false negative': 0.46043656207366984,
#    'false positive': 0.0,
#    'time': 2.6953229904174805}},
#  'k = 6, n = 8': {'kernel_metric': {'auc': 0.99966943016056242,
#    'false negative': 0.12926330150068213,
#    'false positive': 0.0,
#    'time': 9.90650200843811},
#   'support_vectors_metric': {'auc': 0.98322804071780878,
#    'false negative': 0.19952251023192361,
#    'false positive': 0.0092307692307692316,
#    'time': 0.29776906967163086},
#   'validate_classifier_by_random_points': {'auc': 0.99851191100850034,
#    'false negative': 0.1432469304229195,
#    'false positive': 0.0030769230769230769,
#    'time': 5.05681300163269}},
#  'k = 7, n = 11': {'kernel_metric': {'auc': 0.99964646332188101,
#    'false negative': 0.11796795090351177,
#    'false positive': 0.0,
#    'time': 10.395903825759888},
#   'support_vectors_metric': {'auc': 0.96211702378766817,
#    'false negative': 0.33924309580634165,
#    'false positive': 0.0,
#    'time': 0.35347914695739746},
#   'validate_classifier_by_random_points': {'auc': 0.97291195677830522,
#    'false negative': 0.088646437095124445,
#    'false positive': 0.067692307692307691,
#    'time': 6.613194227218628}},
#  'k = 7, n = 14': {'kernel_metric': {'auc': 0.99991607437908159,
#    'false negative': 0.093078758949880672,
#    'false positive': 0.0,
#    'time': 11.048264980316162},
#   'support_vectors_metric': {'auc': 0.89940150541582531,
#    'false negative': 0.3303784520968292,
#    'false positive': 0.0092307692307692316,
#    'time': 0.3913729190826416},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.263434171676636}},
#  'k = 7, n = 17': {'kernel_metric': {'auc': 0.98275643211204078,
#    'false negative': 0.08660075008523696,
#    'false positive': 0.027692307692307693,
#    'time': 11.869118928909302},
#   'support_vectors_metric': {'auc': 0.78708909229195623,
#    'false negative': 0.19877258779406751,
#    'false positive': 0.53230769230769226,
#    'time': 0.43646812438964844},
#   'validate_classifier_by_random_points': {'auc': 0.7884046263998532,
#    'false negative': 0.082850323900443237,
#    'false positive': 0.94153846153846155,
#    'time': 16.378988027572632}},
#  'k = 7, n = 2': {'kernel_metric': {'auc': 0.95452175509454751,
#    'false negative': 0.98056597340606888,
#    'false positive': 0.0030769230769230769,
#    'time': 8.870073080062866},
#   'support_vectors_metric': {'auc': 0.9937328542579138,
#    'false negative': 0.80838731674053865,
#    'false positive': 0.0030769230769230769,
#    'time': 0.19516897201538086},
#   'validate_classifier_by_random_points': {'auc': 0.98292323428361605,
#    'false negative': 0.88203204909648825,
#    'false positive': 0.0030769230769230769,
#    'time': 1.505436897277832}},
#  'k = 7, n = 20': {'kernel_metric': {'auc': 0.95602402370898798,
#    'false negative': 0.10944425502898057,
#    'false positive': 0.080000000000000002,
#    'time': 12.909662961959839},
#   'support_vectors_metric': {'auc': 0.64601746701985363,
#    'false negative': 0.15138083873167404,
#    'false positive': 0.99384615384615382,
#    'time': 0.5144569873809814},
#   'validate_classifier_by_random_points': {'auc': 0.74986283406331133,
#    'false negative': 0.097511080804636885,
#    'false positive': 0.98461538461538467,
#    'time': 22.039071083068848}},
#  'k = 7, n = 23': {'kernel_metric': {'auc': 0.92320176243803931,
#    'false negative': 0.17388339584043641,
#    'false positive': 0.070769230769230765,
#    'time': 12.832772016525269},
#   'support_vectors_metric': {'auc': 0.40562931102310573,
#    'false negative': 0.085577906580293212,
#    'false positive': 1.0,
#    'time': 0.5392611026763916},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 25.35958194732666}},
#  'k = 7, n = 26': {'kernel_metric': {'auc': 0.23401085787720632,
#    'false negative': 0.29901125127855438,
#    'false positive': 1.0,
#    'time': 14.16615605354309},
#   'support_vectors_metric': {'auc': 0.13878989745338194,
#    'false negative': 0.37538356631435388,
#    'false positive': 1.0,
#    'time': 0.6305980682373047},
#   'validate_classifier_by_random_points': {'auc': 0.15216344514673869,
#    'false negative': 0.26184793726559835,
#    'false positive': 1.0,
#    'time': 29.90839385986328}},
#  'k = 7, n = 29': {'kernel_metric': {'auc': 0.31674788218940964,
#    'false negative': 0.067848619161268331,
#    'false positive': 1.0,
#    'time': 14.393442869186401},
#   'support_vectors_metric': {'auc': 0.13545070681108867,
#    'false negative': 0.082850323900443237,
#    'false positive': 1.0,
#    'time': 0.703434944152832},
#   'validate_classifier_by_random_points': {'auc': 0.31674788218940964,
#    'false negative': 0.067848619161268331,
#    'false positive': 1.0,
#    'time': 34.94382882118225}},
#  'k = 7, n = 5': {'kernel_metric': {'auc': 0.99674998032993256,
#    'false negative': 0.49676099556767817,
#    'false positive': 0.0030769230769230769,
#    'time': 9.381777048110962},
#   'support_vectors_metric': {'auc': 0.99213931653072462,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.26075100898742676},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.074173927307129}},
#  'k = 7, n = 8': {'kernel_metric': {'auc': 0.99997482231372437,
#    'false negative': 0.21377429253324243,
#    'false positive': 0.0,
#    'time': 9.885138034820557},
#   'support_vectors_metric': {'auc': 0.9970111988250413,
#    'false negative': 0.95772246846232523,
#    'false positive': 0.0,
#    'time': 0.31346607208251953},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.519338846206665}},
#  'k = 8, n = 11': {'kernel_metric': {'auc': 0.99838023551627375,
#    'false negative': 0.14251619502216162,
#    'false positive': 0.0030769230769230769,
#    'time': 12.54823899269104},
#   'support_vectors_metric': {'auc': 0.96576673922735967,
#    'false negative': 0.96726900784180025,
#    'false positive': 0.0,
#    'time': 0.3603031635284424},
#   'validate_classifier_by_random_points': {'auc': 0.96569959873062494,
#    'false negative': 0.10160245482441187,
#    'false positive': 0.049230769230769231,
#    'time': 8.830522060394287}},
#  'k = 8, n = 14': {'kernel_metric': {'auc': 0.99962758005717434,
#    'false negative': 0.23491305830207979,
#    'false positive': 0.0,
#    'time': 12.899358034133911},
#   'support_vectors_metric': {'auc': 0.93172231110178605,
#    'false negative': 0.98295260825093755,
#    'false positive': 0.0,
#    'time': 0.4234459400177002},
#   'validate_classifier_by_random_points': {'auc': 0.99962758005717434,
#    'false negative': 0.23491305830207979,
#    'false positive': 0.0,
#    'time': 12.227622032165527}},
#  'k = 8, n = 17': {'kernel_metric': {'auc': 0.97958509271158434,
#    'false negative': 0.073985680190930783,
#    'false positive': 0.043076923076923075,
#    'time': 11.980647087097168},
#   'support_vectors_metric': {'auc': 0.81280704975215723,
#    'false negative': 0.26252983293556087,
#    'false positive': 0.19692307692307692,
#    'time': 0.48156309127807617},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.925400972366333}},
#  'k = 8, n = 2': {'kernel_metric': {'auc': 0.78400430118807207,
#    'false negative': 0.97545175588135014,
#    'false positive': 0.0,
#    'time': 9.547049045562744},
#   'support_vectors_metric': {'auc': 0.97734637677358438,
#    'false negative': 0.9979543129901125,
#    'false positive': 0.0,
#    'time': 0.20795178413391113},
#   'validate_classifier_by_random_points': {'auc': 0.60327677096173504,
#    'false negative': 0.98056597340606888,
#    'false positive': 0.0030769230769230769,
#    'time': 1.5436739921569824}},
#  'k = 8, n = 20': {'kernel_metric': {'auc': 0.94093839334889451,
#    'false negative': 0.15206273440163656,
#    'false positive': 0.083076923076923076,
#    'time': 12.839624166488647},
#   'support_vectors_metric': {'auc': 0.54451782108106694,
#    'false negative': 0.14558472553699284,
#    'false positive': 0.99692307692307691,
#    'time': 0.5036649703979492},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 20.649805068969727}},
#  'k = 8, n = 23': {'kernel_metric': {'auc': 0.95920585381205903,
#    'false negative': 0.14251619502216162,
#    'false positive': 0.052307692307692305,
#    'time': 13.43943190574646},
#   'support_vectors_metric': {'auc': 0.4129371344645808,
#    'false negative': 0.098192976474599389,
#    'false positive': 1.0,
#    'time': 0.5819170475006104},
#   'validate_classifier_by_random_points': {'auc': 0.4129371344645808,
#    'false negative': 0.098192976474599389,
#    'false positive': 1.0,
#    'time': 27.133493185043335}},
#  'k = 8, n = 26': {'kernel_metric': {'auc': 0.37026829971937369,
#    'false negative': 0.12274122059324924,
#    'false positive': 1.0,
#    'time': 13.627422094345093},
#   'support_vectors_metric': {'auc': 0.2107645099530541,
#    'false negative': 0.1039890896692806,
#    'false positive': 1.0,
#    'time': 0.6517617702484131},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.98430585861206}},
#  'k = 8, n = 29': {'kernel_metric': {'auc': 0.27668598704398223,
#    'false negative': 0.087964541425161955,
#    'false positive': 1.0,
#    'time': 14.049728870391846},
#   'support_vectors_metric': {'auc': 0.11972829080227648,
#    'false negative': 0.070576201841118305,
#    'false positive': 1.0,
#    'time': 0.6605269908905029},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 31.19312286376953}},
#  'k = 8, n = 5': {'kernel_metric': {'auc': 0.99788717249337766,
#    'false negative': 0.98363450392090013,
#    'false positive': 0.0,
#    'time': 10.508416891098022},
#   'support_vectors_metric': {'auc': 0.99652128301292986,
#    'false negative': 0.6348448687350835,
#    'false positive': 0.0,
#    'time': 0.2867000102996826},
#   'validate_classifier_by_random_points': {'auc': 0.50818274803954999,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.920844793319702}},
#  'k = 8, n = 8': {'kernel_metric': {'auc': 0.99988250413071422,
#    'false negative': 0.18342993521991136,
#    'false positive': 0.0,
#    'time': 10.93350100517273},
#   'support_vectors_metric': {'auc': 0.98960371370872569,
#    'false negative': 0.68666893965223319,
#    'false positive': 0.0,
#    'time': 0.4698948860168457},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.013003826141357}},
#  'k = 9, n = 11': {'kernel_metric': {'auc': 0.99993806261974127,
#    'false negative': 0.071306721255544186,
#    'false positive': 0.0,
#    'time': 11.039995908737183},
#   'support_vectors_metric': {'auc': 0.97231294123822243,
#    'false negative': 0.13988399863527806,
#    'false positive': 0.027692307692307693,
#    'time': 0.3555269241333008},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.511781930923462}},
#  'k = 9, n = 14': {'kernel_metric': {'auc': 0.99957378684093112,
#    'false negative': 0.11941316956670078,
#    'false positive': 0.0,
#    'time': 11.303028106689453},
#   'support_vectors_metric': {'auc': 0.92384746607878665,
#    'false negative': 0.55817127260320709,
#    'false positive': 0.0,
#    'time': 0.39480113983154297},
#   'validate_classifier_by_random_points': {'auc': 0.99966616801826624,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 10.268010139465332}},
#  'k = 9, n = 17': {'kernel_metric': {'auc': 0.95712778521376263,
#    'false negative': 0.11804844762879563,
#    'false positive': 0.061538461538461542,
#    'time': 11.683290958404541},
#   'support_vectors_metric': {'auc': 0.71414429310028071,
#    'false negative': 0.34732173319686116,
#    'false positive': 0.29230769230769232,
#    'time': 0.4483828544616699},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 16.064934015274048}},
#  'k = 9, n = 2': {'kernel_metric': {'auc': 0.8729632837309399,
#    'false negative': 0.89935175707949511,
#    'false positive': 0.0061538461538461538,
#    'time': 9.115413188934326},
#   'support_vectors_metric': {'auc': 0.99609269611316698,
#    'false negative': 0.58785397475264412,
#    'false positive': 0.0030769230769230769,
#    'time': 0.2111051082611084},
#   'validate_classifier_by_random_points': {'auc': 0.99609269611316698,
#    'false negative': 0.58751279426816783,
#    'false positive': 0.0030769230769230769,
#    'time': 1.4331958293914795}},
#  'k = 9, n = 20': {'kernel_metric': {'auc': 0.85992389050730911,
#    'false negative': 0.30092118730808598,
#    'false positive': 0.070769230769230765,
#    'time': 12.667114973068237},
#   'support_vectors_metric': {'auc': 0.43421042962496392,
#    'false negative': 0.38826339133401572,
#    'false positive': 0.93846153846153846,
#    'time': 0.4936559200286865},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 23.580904006958008}},
#  'k = 9, n = 23': {'kernel_metric': {'auc': 0.91010051701965733,
#    'false negative': 0.26816786079836236,
#    'false positive': 0.040000000000000001,
#    'time': 12.90123987197876},
#   'support_vectors_metric': {'auc': 0.38051701965724483,
#    'false negative': 0.23643807574206754,
#    'false positive': 1.0,
#    'time': 0.602869987487793},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 25.064898014068604}},
#  'k = 9, n = 26': {'kernel_metric': {'auc': 0.86151851560244608,
#    'false negative': 0.36881610371886731,
#    'false positive': 0.049230769230769231,
#    'time': 13.792641878128052},
#   'support_vectors_metric': {'auc': 0.24236306852478809,
#    'false negative': 0.088024564994882287,
#    'false positive': 1.0,
#    'time': 0.6042759418487549},
#   'validate_classifier_by_random_points': {'auc': 0.88512400598378083,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.573198080062866}},
#  'k = 9, n = 29': {'kernel_metric': {'auc': 0.2752675642337874,
#    'false negative': 0.069941999317639031,
#    'false positive': 1.0,
#    'time': 13.962913036346436},
#   'support_vectors_metric': {'auc': 0.11419363304726661,
#    'false negative': 0.096554077106789496,
#    'false positive': 1.0,
#    'time': 0.6557431221008301},
#   'validate_classifier_by_random_points': {'auc': 0.13264572343385034,
#    'false negative': 0.079836233367451381,
#    'false positive': 1.0,
#    'time': 33.64978289604187}},
#  'k = 9, n = 5': {'kernel_metric': {'auc': 0.9999233656142561,
#    'false negative': 0.21426134425110885,
#    'false positive': 0.0,
#    'time': 9.539765119552612},
#   'support_vectors_metric': {'auc': 0.99878959661968869,
#    'false negative': 0.5881951552371204,
#    'false positive': 0.0,
#    'time': 0.25046777725219727},
#   'validate_classifier_by_random_points': {'auc': 0.50153531218014324,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.436450958251953}},
#  'k = 9, n = 8': {'kernel_metric': {'auc': 0.99994856048080205,
#    'false negative': 0.29068577277379731,
#    'false positive': 0.0,
#    'time': 10.068763017654419},
#   'support_vectors_metric': {'auc': 0.99647901740020473,
#    'false negative': 0.87205731832139199,
#    'false positive': 0.0,
#    'time': 0.301530122756958},
#   'validate_classifier_by_random_points': {'auc': 0.99647901740020473,
#    'false negative': 0.87205731832139199,
#    'false positive': 0.0,
#    'time': 5.347978830337524}}}

# %% [raw]
# process_data_set(data)

# %%
results_previous = results

# %%
results
# Out:
# {'k = 1, n = 11': {'kernel_metric': {'auc': 0.99998426394607776,
#    'false negative': 0.12376406409819297,
#    'false positive': 0.0,
#    'time': 26.952219009399414},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8779561519622803},
#   'validate_classifier_by_random_points': {'auc': 0.99491515644260275,
#    'false negative': 0.10126150698943062,
#    'false positive': 0.0030769230769230769,
#    'time': 18.51043701171875}},
#  'k = 1, n = 14': {'kernel_metric': {'auc': 0.99874426289700757,
#    'false negative': 0.13262870780770541,
#    'false positive': 0.0,
#    'time': 28.582165956497192},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.0195338726043701},
#   'validate_classifier_by_random_points': {'auc': 0.89768837367882703,
#    'false negative': 0.093419706784861917,
#    'false positive': 0.39076923076923076,
#    'time': 29.771906852722168}},
#  'k = 1, n = 17': {'kernel_metric': {'auc': 0.99279813265493455,
#    'false negative': 0.12205932492328674,
#    'false positive': 0.0061538461538461538,
#    'time': 29.32083010673523},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.101388931274414},
#   'validate_classifier_by_random_points': {'auc': 0.66719609745862729,
#    'false negative': 0.71496760995567676,
#    'false positive': 0.0061538461538461538,
#    'time': 35.015021085739136}},
#  'k = 1, n = 2': {'kernel_metric': {'auc': 0.99818301030711543,
#    'false negative': 0.10910330719399931,
#    'false positive': 0.0030769230769230769,
#    'time': 22.96292519569397},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5771009922027588},
#   'validate_classifier_by_random_points': {'auc': 0.9974581027564321,
#    'false negative': 0.4145925673371974,
#    'false positive': 0.0030769230769230769,
#    'time': 3.7719058990478516}},
#  'k = 1, n = 20': {'kernel_metric': {'auc': 0.98669569094390108,
#    'false negative': 0.14660756904193659,
#    'false positive': 0.0,
#    'time': 31.060063123703003},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2678680419921875},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 52.21058392524719}},
#  'k = 1, n = 23': {'kernel_metric': {'auc': 0.88442078208187991,
#    'false negative': 0.11592226389362427,
#    'false positive': 0.41230769230769232,
#    'time': 32.41856002807617},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3903841972351074},
#   'validate_classifier_by_random_points': {'auc': 0.88442078208187991,
#    'false negative': 0.11592226389362427,
#    'false positive': 0.41230769230769232,
#    'time': 61.48767399787903}},
#  'k = 1, n = 26': {'kernel_metric': {'auc': 0.69019276666054696,
#    'false negative': 0.16297306512103649,
#    'false positive': 0.87076923076923074,
#    'time': 33.62850618362427},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.529162883758545},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 70.31953501701355}},
#  'k = 1, n = 29': {'kernel_metric': {'auc': 0.41435233024731832,
#    'false negative': 0.1118308898738493,
#    'false positive': 1.0,
#    'time': 35.10407304763794},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6969540119171143},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 68.36350512504578}},
#  'k = 1, n = 5': {'kernel_metric': {'auc': 1.0,
#    'false negative': 0.32526423457211046,
#    'false positive': 0.0,
#    'time': 24.215362071990967},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6484529972076416},
#   'validate_classifier_by_random_points': {'auc': 0.50119331742243434,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.662806987762451}},
#  'k = 1, n = 8': {'kernel_metric': {'auc': 0.99997482231372448,
#    'false negative': 0.16911012615069895,
#    'false positive': 0.0,
#    'time': 25.3720440864563},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8097889423370361},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 12.726601839065552}},
#  'k = 10, n = 11': {'kernel_metric': {'auc': 0.99996852789215551,
#    'false negative': 0.09648823729969315,
#    'false positive': 0.0,
#    'time': 26.50637698173523},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8482110500335693},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.883074045181274}},
#  'k = 10, n = 14': {'kernel_metric': {'auc': 0.99956463584148558,
#    'false negative': 0.15581316058643027,
#    'false positive': 0.0,
#    'time': 28.873677015304565},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.008246898651123},
#   'validate_classifier_by_random_points': {'auc': 0.93200870728317042,
#    'false negative': 0.69689737470167068,
#    'false positive': 0.0,
#    'time': 28.240421056747437}},
#  'k = 10, n = 17': {'kernel_metric': {'auc': 0.99287366571376112,
#    'false negative': 0.11830889873849301,
#    'false positive': 0.0030769230769230769,
#    'time': 33.62712597846985},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1291241645812988},
#   'validate_classifier_by_random_points': {'auc': 0.80491804138582179,
#    'false negative': 0.97920218206614384,
#    'false positive': 0.0,
#    'time': 47.93847990036011}},
#  'k = 10, n = 2': {'kernel_metric': {'auc': 0.9711232919824806,
#    'false negative': 0.72894647118990796,
#    'false positive': 0.0030769230769230769,
#    'time': 22.21839189529419},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.4916071891784668},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.6962149143218994}},
#  'k = 10, n = 20': {'kernel_metric': {'auc': 0.97795693566576614,
#    'false negative': 0.12887828162291171,
#    'false positive': 0.015384615384615385,
#    'time': 30.971271991729736},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2361149787902832},
#   'validate_classifier_by_random_points': {'auc': 0.57651866033727606,
#    'false negative': 0.42891237640640983,
#    'false positive': 0.4276923076923077,
#    'time': 55.50100088119507}},
#  'k = 10, n = 23': {'kernel_metric': {'auc': 0.75394791366151759,
#    'false negative': 0.17763382202523015,
#    'false positive': 0.60307692307692307,
#    'time': 32.1387939453125},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3863639831542969},
#   'validate_classifier_by_random_points': {'auc': 0.36776416900521913,
#    'false negative': 0.16501875213092396,
#    'false positive': 1.0,
#    'time': 64.21425580978394}},
#  'k = 10, n = 26': {'kernel_metric': {'auc': 0.68402633166356308,
#    'false negative': 0.21513808387316741,
#    'false positive': 0.7138461538461538,
#    'time': 35.02934694290161},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4973571300506592},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 71.44950819015503}},
#  'k = 10, n = 29': {'kernel_metric': {'auc': 0.24852684308531564,
#    'false negative': 0.21513808387316741,
#    'false positive': 1.0,
#    'time': 34.792009115219116},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6405410766601562},
#   'validate_classifier_by_random_points': {'auc': 0.095212567861732531,
#    'false negative': 0.25741561541084212,
#    'false positive': 1.0,
#    'time': 78.70283007621765}},
#  'k = 10, n = 5': {'kernel_metric': {'auc': 1.0,
#    'false negative': 0.69110126150698947,
#    'false positive': 0.0,
#    'time': 24.141765832901},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6445541381835938},
#   'validate_classifier_by_random_points': {'auc': 0.8235594953972043,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.6096320152282715}},
#  'k = 10, n = 8': {'kernel_metric': {'auc': 0.99936845970258859,
#    'false negative': 0.14456188203204909,
#    'false positive': 0.0,
#    'time': 24.79592800140381},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7533259391784668},
#   'validate_classifier_by_random_points': {'auc': 0.9924750190143985,
#    'false negative': 0.15922263893624275,
#    'false positive': 0.0,
#    'time': 13.647481203079224}},
#  'k = 11, n = 11': {'kernel_metric': {'auc': 0.99979648036927271,
#    'false negative': 0.068189566996249576,
#    'false positive': 0.0,
#    'time': 26.352689027786255},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7897779941558838},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 23.310580015182495}},
#  'k = 11, n = 14': {'kernel_metric': {'auc': 0.99936531249180416,
#    'false negative': 0.13399249914763042,
#    'false positive': 0.0,
#    'time': 30.46465492248535},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.984468936920166},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 28.24903893470764}},
#  'k = 11, n = 17': {'kernel_metric': {'auc': 0.98960790998977166,
#    'false negative': 0.094783498124786911,
#    'false positive': 0.012307692307692308,
#    'time': 29.39295220375061},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1347858905792236},
#   'validate_classifier_by_random_points': {'auc': 0.80685305148312314,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 43.59950494766235}},
#  'k = 11, n = 2': {'kernel_metric': {'auc': 0.95618925227517115,
#    'false negative': 0.76747357654278892,
#    'false positive': 0.015384615384615385,
#    'time': 22.2824490070343},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5034220218658447},
#   'validate_classifier_by_random_points': {'auc': 0.50017047391749059,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.758629083633423}},
#  'k = 11, n = 20': {'kernel_metric': {'auc': 0.96735817881402608,
#    'false negative': 0.20797817933856119,
#    'false positive': 0.0030769230769230769,
#    'time': 32.91632413864136},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2619678974151611},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 58.678871870040894}},
#  'k = 11, n = 23': {'kernel_metric': {'auc': 0.80455086679430354,
#    'false negative': 0.13058302079781794,
#    'false positive': 0.6676923076923077,
#    'time': 35.21823215484619},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.368671178817749},
#   'validate_classifier_by_random_points': {'auc': 0.56493272836948261,
#    'false negative': 0.12069553358336174,
#    'false positive': 1.0,
#    'time': 66.14366888999939}},
#  'k = 11, n = 26': {'kernel_metric': {'auc': 0.65983162422303243,
#    'false negative': 0.29798840777361063,
#    'false positive': 0.56000000000000005,
#    'time': 33.45369100570679},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.5447640419006348},
#   'validate_classifier_by_random_points': {'auc': 0.20350599281386869,
#    'false negative': 0.17320150017047392,
#    'false positive': 1.0,
#    'time': 70.0890588760376}},
#  'k = 11, n = 29': {'kernel_metric': {'auc': 0.31618977681030186,
#    'false negative': 0.098533924309580634,
#    'false positive': 1.0,
#    'time': 35.237725019454956},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.634925127029419},
#   'validate_classifier_by_random_points': {'auc': 0.12955073566052086,
#    'false negative': 0.10330719399931811,
#    'false positive': 1.0,
#    'time': 79.16757607460022}},
#  'k = 11, n = 5': {'kernel_metric': {'auc': 0.99493823598835518,
#    'false negative': 0.66177974769860215,
#    'false positive': 0.0,
#    'time': 23.51276183128357},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5797009468078613},
#   'validate_classifier_by_random_points': {'auc': 0.99236224396128947,
#    'false negative': 0.72246846232526418,
#    'false positive': 0.0,
#    'time': 8.496994972229004}},
#  'k = 11, n = 8': {'kernel_metric': {'auc': 0.99955414513887064,
#    'false negative': 0.34742584384589159,
#    'false positive': 0.0,
#    'time': 24.879758834838867},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7278079986572266},
#   'validate_classifier_by_random_points': {'auc': 0.98051981431456381,
#    'false negative': 0.085236958745311966,
#    'false positive': 0.052307692307692305,
#    'time': 19.752968072891235}},
#  'k = 12, n = 11': {'kernel_metric': {'auc': 0.99939133172421035,
#    'false negative': 0.21555252387448839,
#    'false positive': 0.0,
#    'time': 26.203417778015137},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8370192050933838},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 22.23464608192444}},
#  'k = 12, n = 14': {'kernel_metric': {'auc': 0.99469828943225924,
#    'false negative': 0.34311050477489768,
#    'false positive': 0.0,
#    'time': 27.881640195846558},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9791510105133057},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.199536085128784}},
#  'k = 12, n = 17': {'kernel_metric': {'auc': 0.98472137684961702,
#    'false negative': 0.1340381991814461,
#    'false positive': 0.0061538461538461538,
#    'time': 30.068721055984497},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3262040615081787},
#   'validate_classifier_by_random_points': {'auc': 0.77578444747612552,
#    'false negative': 0.10197817189631651,
#    'false positive': 0.88615384615384618,
#    'time': 41.54409384727478}},
#  'k = 12, n = 2': {'kernel_metric': {'auc': 0.97947213768496166,
#    'false negative': 0.97885402455661663,
#    'false positive': 0.0061538461538461538,
#    'time': 22.304913997650146},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.49576902389526367},
#   'validate_classifier_by_random_points': {'auc': 0.98982159722950991,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.7516579627990723}},
#  'k = 12, n = 20': {'kernel_metric': {'auc': 0.96947108825689987,
#    'false negative': 0.17939972714870395,
#    'false positive': 0.0092307692307692316,
#    'time': 34.516380071640015},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3275330066680908},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 68.3364109992981}},
#  'k = 12, n = 23': {'kernel_metric': {'auc': 0.84286598803652013,
#    'false negative': 0.095497953615279671,
#    'false positive': 0.64923076923076928,
#    'time': 33.39739203453064},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3941419124603271},
#   'validate_classifier_by_random_points': {'auc': 0.40897365935565116,
#    'false negative': 0.080491132332878579,
#    'false positive': 1.0,
#    'time': 65.96810102462769}},
#  'k = 12, n = 26': {'kernel_metric': {'auc': 0.70596285024661565,
#    'false negative': 0.19031377899045021,
#    'false positive': 0.71999999999999997,
#    'time': 33.97605299949646},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6644258499145508},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 79.93171381950378}},
#  'k = 12, n = 29': {'kernel_metric': {'auc': 0.32900514219750238,
#    'false negative': 0.11698499317871761,
#    'false positive': 1.0,
#    'time': 34.74323010444641},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.719581127166748},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 79.8323769569397}},
#  'k = 12, n = 5': {'kernel_metric': {'auc': 0.99699024031902617,
#    'false negative': 0.65654843110504779,
#    'false positive': 0.0030769230769230769,
#    'time': 23.791685104370117},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6486611366271973},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.059706211090088}},
#  'k = 12, n = 8': {'kernel_metric': {'auc': 0.99980585580858428,
#    'false negative': 0.18008185538881311,
#    'false positive': 0.0,
#    'time': 25.658179998397827},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7532801628112793},
#   'validate_classifier_by_random_points': {'auc': 0.98571098751180597,
#    'false negative': 0.52523874488403821,
#    'false positive': 0.0,
#    'time': 14.820677042007446}},
#  'k = 13, n = 11': {'kernel_metric': {'auc': 0.99904719384405283,
#    'false negative': 0.14749061113007852,
#    'false positive': 0.0,
#    'time': 27.0592041015625},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8649251461029053},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.14465093612671}},
#  'k = 13, n = 14': {'kernel_metric': {'auc': 0.99417496126270455,
#    'false negative': 0.24274496415158758,
#    'false positive': 0.0,
#    'time': 28.9862380027771},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.012943983078003},
#   'validate_classifier_by_random_points': {'auc': 0.85504530293878189,
#    'false negative': 0.39091840218504609,
#    'false positive': 0.018461538461538463,
#    'time': 28.69154715538025}},
#  'k = 13, n = 17': {'kernel_metric': {'auc': 0.98111510885836584,
#    'false negative': 0.12427449641515875,
#    'false positive': 0.0092307692307692316,
#    'time': 32.48502588272095},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1309120655059814},
#   'validate_classifier_by_random_points': {'auc': 0.7784352758883315,
#    'false negative': 0.20518948446568794,
#    'false positive': 0.47692307692307695,
#    'time': 40.10030388832092}},
#  'k = 13, n = 2': {'kernel_metric': {'auc': 0.97555059484728313,
#    'false negative': 0.62103106862410384,
#    'false positive': 0.0092307692307692316,
#    'time': 22.53142809867859},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.48699307441711426},
#   'validate_classifier_by_random_points': {'auc': 0.97744990414160771,
#    'false negative': 0.50665756230795489,
#    'false positive': 0.012307692307692308,
#    'time': 3.6479389667510986}},
#  'k = 13, n = 20': {'kernel_metric': {'auc': 0.96791659006749486,
#    'false negative': 0.22396722430863775,
#    'false positive': 0.0061538461538461538,
#    'time': 30.342128038406372},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2838280200958252},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 49.275644063949585}},
#  'k = 13, n = 23': {'kernel_metric': {'auc': 0.81438873860860894,
#    'false negative': 0.16148856264936839,
#    'false positive': 0.48307692307692307,
#    'time': 31.68607211112976},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3509840965270996},
#   'validate_classifier_by_random_points': {'auc': 0.95588675578433169,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 63.49627113342285}},
#  'k = 13, n = 26': {'kernel_metric': {'auc': 0.7593928093074559,
#    'false negative': 0.17480368726527826,
#    'false positive': 0.66461538461538461,
#    'time': 33.17754793167114},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.5047838687896729},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 63.70211100578308}},
#  'k = 13, n = 29': {'kernel_metric': {'auc': 0.25912755731806603,
#    'false negative': 0.16421987026288837,
#    'false positive': 1.0,
#    'time': 36.64388585090637},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6067631244659424},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 81.30502796173096}},
#  'k = 13, n = 5': {'kernel_metric': {'auc': 0.9944733040943351,
#    'false negative': 0.74257425742574257,
#    'false positive': 0.0,
#    'time': 23.75272011756897},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6602540016174316},
#   'validate_classifier_by_random_points': {'auc': 0.99770885311342805,
#    'false negative': 0.22396722430863775,
#    'false positive': 0.0030769230769230769,
#    'time': 8.36208200454712}},
#  'k = 13, n = 8': {'kernel_metric': {'auc': 0.99983927305197362,
#    'false negative': 0.39638101741208603,
#    'false positive': 0.0,
#    'time': 24.96591091156006},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7650759220123291},
#   'validate_classifier_by_random_points': {'auc': 0.98748956062715032,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 16.526299953460693}},
#  'k = 14, n = 11': {'kernel_metric': {'auc': 0.99991913888159611,
#    'false negative': 0.1348122866894198,
#    'false positive': 0.0,
#    'time': 27.029079914093018},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9140799045562744},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.75287890434265}},
#  'k = 14, n = 14': {'kernel_metric': {'auc': 0.99743554738776585,
#    'false negative': 0.14744027303754267,
#    'false positive': 0.0,
#    'time': 27.726598978042603},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9774069786071777},
#   'validate_classifier_by_random_points': {'auc': 0.84021948017852455,
#    'false negative': 0.095904436860068262,
#    'false positive': 0.71692307692307689,
#    'time': 31.70378088951111}},
#  'k = 14, n = 17': {'kernel_metric': {'auc': 0.9823365712785509,
#    'false negative': 0.13924914675767919,
#    'false positive': 0.012307692307692308,
#    'time': 30.195612907409668},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1068530082702637},
#   'validate_classifier_by_random_points': {'auc': 0.74886636912575488,
#    'false negative': 0.99863481228668938,
#    'false positive': 0.0,
#    'time': 42.243430852890015}},
#  'k = 14, n = 2': {'kernel_metric': {'auc': 0.9627513783145184,
#    'false negative': 0.74129692832764504,
#    'false positive': 0.012307692307692308,
#    'time': 22.978883028030396},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.48290419578552246},
#   'validate_classifier_by_random_points': {'auc': 0.97418325019690211,
#    'false negative': 0.5897610921501707,
#    'false positive': 0.0061538461538461538,
#    'time': 3.800373077392578}},
#  'k = 14, n = 20': {'kernel_metric': {'auc': 0.97492045156208984,
#    'false negative': 0.20204778156996586,
#    'false positive': 0.0030769230769230769,
#    'time': 30.334117889404297},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.259995937347412},
#   'validate_classifier_by_random_points': {'auc': 0.58713258072985042,
#    'false negative': 0.12252559726962457,
#    'false positive': 0.99384615384615382,
#    'time': 51.64894914627075}},
#  'k = 14, n = 23': {'kernel_metric': {'auc': 0.86940089262273568,
#    'false negative': 0.10375426621160409,
#    'false positive': 0.52923076923076928,
#    'time': 32.06380105018616},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3621509075164795},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 58.79226303100586}},
#  'k = 14, n = 26': {'kernel_metric': {'auc': 0.70819847729062735,
#    'false negative': 0.16313993174061434,
#    'false positive': 0.78769230769230769,
#    'time': 33.5721549987793},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.49721097946167},
#   'validate_classifier_by_random_points': {'auc': 0.83422945655027569,
#    'false negative': 0.70307167235494883,
#    'false positive': 0.0,
#    'time': 72.80779004096985}},
#  'k = 14, n = 29': {'kernel_metric': {'auc': 0.29342714623260696,
#    'false negative': 0.12901023890784982,
#    'false positive': 1.0,
#    'time': 34.54658102989197},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6119840145111084},
#   'validate_classifier_by_random_points': {'auc': 0.57055710160147011,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 77.31965184211731}},
#  'k = 14, n = 5': {'kernel_metric': {'auc': 0.99833552113415602,
#    'false negative': 0.95085324232081914,
#    'false positive': 0.0,
#    'time': 24.096276998519897},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6416239738464355},
#   'validate_classifier_by_random_points': {'auc': 0.99833552113415602,
#    'false negative': 0.95085324232081914,
#    'false positive': 0.0,
#    'time': 9.232630968093872}},
#  'k = 14, n = 8': {'kernel_metric': {'auc': 0.99996324494617994,
#    'false negative': 0.22764505119453926,
#    'false positive': 0.0,
#    'time': 25.007663011550903},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8208239078521729},
#   'validate_classifier_by_random_points': {'auc': 0.99889944867419256,
#    'false negative': 0.04778156996587031,
#    'false positive': 0.0,
#    'time': 16.471590995788574}},
#  'k = 2, n = 11': {'kernel_metric': {'auc': 0.99911563376957169,
#    'false negative': 0.44425502898056596,
#    'false positive': 0.0,
#    'time': 26.626376152038574},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8652710914611816},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 25.871605157852173}},
#  'k = 2, n = 14': {'kernel_metric': {'auc': 0.99992131973038889,
#    'false negative': 0.020797817933856121,
#    'false positive': 0.0,
#    'time': 27.955672025680542},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.0028789043426514},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 33.96308612823486}},
#  'k = 2, n = 17': {'kernel_metric': {'auc': 0.94612394765139385,
#    'false negative': 0.4047050801227412,
#    'false positive': 0.0,
#    'time': 29.339652061462402},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2026331424713135},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 38.37271785736084}},
#  'k = 2, n = 2': {'kernel_metric': {'auc': 0.98948307062865537,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 22.53406810760498},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.490070104598999},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.7657630443573}},
#  'k = 2, n = 20': {'kernel_metric': {'auc': 0.95703322930053236,
#    'false negative': 0.3303784520968292,
#    'false positive': 0.0061538461538461538,
#    'time': 30.81985902786255},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.268301010131836},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 44.2973370552063}},
#  'k = 2, n = 23': {'kernel_metric': {'auc': 0.85718691809383929,
#    'false negative': 0.10296624616433686,
#    'false positive': 0.55076923076923079,
#    'time': 32.231109857559204},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3693368434906006},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 62.632153034210205}},
#  'k = 2, n = 26': {'kernel_metric': {'auc': 0.7979312334443599,
#    'false negative': 0.10910330719399931,
#    'false positive': 0.74769230769230766,
#    'time': 33.73489308357239},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.517207145690918},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 74.34835505485535}},
#  'k = 2, n = 29': {'kernel_metric': {'auc': 0.43508510582496263,
#    'false negative': 0.049437436072280939,
#    'false positive': 1.0,
#    'time': 42.89113998413086},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6291661262512207},
#   'validate_classifier_by_random_points': {'auc': 0.87137559338036663,
#    'false negative': 0.98192976474599392,
#    'false positive': 0.0,
#    'time': 98.58119010925293}},
#  'k = 2, n = 5': {'kernel_metric': {'auc': 0.99839282435941157,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 23.774521112442017},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.666450023651123},
#   'validate_classifier_by_random_points': {'auc': 0.99737942248682121,
#    'false negative': 0.65393794749403344,
#    'false positive': 0.0,
#    'time': 7.38800311088562}},
#  'k = 2, n = 8': {'kernel_metric': {'auc': 0.99945343439376855,
#    'false negative': 0.81111489942038872,
#    'false positive': 0.0,
#    'time': 25.194741010665894},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7624428272247314},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.44603419303894}},
#  'k = 3, n = 11': {'kernel_metric': {'auc': 0.99992866322221929,
#    'false negative': 0.18718036140470509,
#    'false positive': 0.0,
#    'time': 26.296916007995605},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8583848476409912},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 20.09515404701233}},
#  'k = 3, n = 14': {'kernel_metric': {'auc': 0.98835741823808643,
#    'false negative': 0.29423798158881692,
#    'false positive': 0.0,
#    'time': 27.756793975830078},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.0616090297698975},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 30.956066846847534}},
#  'k = 3, n = 17': {'kernel_metric': {'auc': 0.99044821526921767,
#    'false negative': 0.051142175247187178,
#    'false positive': 0.033846153846153845,
#    'time': 29.06406021118164},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2512898445129395},
#   'validate_classifier_by_random_points': {'auc': 0.99778331453749114,
#    'false negative': 0.16604159563586771,
#    'false positive': 0.0,
#    'time': 35.29128408432007}},
#  'k = 3, n = 2': {'kernel_metric': {'auc': 0.48923076923076925,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 22.50399899482727},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5186281204223633},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.5456960201263428}},
#  'k = 3, n = 20': {'kernel_metric': {'auc': 0.9910189094914631,
#    'false negative': 0.10773951585407433,
#    'false positive': 0.0,
#    'time': 30.514535188674927},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2310478687286377},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 51.80460214614868}},
#  'k = 3, n = 23': {'kernel_metric': {'auc': 0.72775787458365027,
#    'false negative': 0.23184452778724854,
#    'false positive': 0.52307692307692311,
#    'time': 31.917041778564453},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3377220630645752},
#   'validate_classifier_by_random_points': {'auc': 0.39727136824988851,
#    'false negative': 0.23048073644732356,
#    'false positive': 1.0,
#    'time': 53.001993894577026}},
#  'k = 3, n = 26': {'kernel_metric': {'auc': 0.66431535052060109,
#    'false negative': 0.29491987725877938,
#    'false positive': 0.5476923076923077,
#    'time': 33.48011302947998},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4541120529174805},
#   'validate_classifier_by_random_points': {'auc': 0.18824621679036951,
#    'false negative': 0.15751789976133651,
#    'false positive': 1.0,
#    'time': 70.93594098091125}},
#  'k = 3, n = 29': {'kernel_metric': {'auc': 0.25261506989430615,
#    'false negative': 0.19365837026934879,
#    'false positive': 1.0,
#    'time': 34.687885999679565},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6280579566955566},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 70.15671396255493}},
#  'k = 3, n = 5': {'kernel_metric': {'auc': 0.9957785412678013,
#    'false negative': 0.99897715649505625,
#    'false positive': 0.0,
#    'time': 23.718343019485474},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6438331604003906},
#   'validate_classifier_by_random_points': {'auc': 0.9988554643447245,
#    'false negative': 0.083191271735424482,
#    'false positive': 0.0030769230769230769,
#    'time': 6.029907941818237}},
#  'k = 3, n = 8': {'kernel_metric': {'auc': 0.99835505782999812,
#    'false negative': 0.36958745311967267,
#    'false positive': 0.0030769230769230769,
#    'time': 24.9655921459198},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7548270225524902},
#   'validate_classifier_by_random_points': {'auc': 0.99929292664376201,
#    'false negative': 0.12205932492328674,
#    'false positive': 0.0030769230769230769,
#    'time': 10.721251964569092}},
#  'k = 4, n = 11': {'kernel_metric': {'auc': 0.99999685278921557,
#    'false negative': 0.026593931128537335,
#    'false positive': 0.0,
#    'time': 26.564724922180176},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.859015941619873},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.603091955184937}},
#  'k = 4, n = 14': {'kernel_metric': {'auc': 0.9973888641191746,
#    'false negative': 0.33481077395158543,
#    'false positive': 0.0,
#    'time': 27.67593288421631},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.0096299648284912},
#   'validate_classifier_by_random_points': {'auc': 0.93249442681423578,
#    'false negative': 0.71189907944084552,
#    'false positive': 0.0,
#    'time': 30.329385995864868}},
#  'k = 4, n = 17': {'kernel_metric': {'auc': 0.99524456450470788,
#    'false negative': 0.076713262870780771,
#    'false positive': 0.012307692307692308,
#    'time': 29.058824062347412},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1155240535736084},
#   'validate_classifier_by_random_points': {'auc': 0.82735660520863386,
#    'false negative': 0.35015342652574155,
#    'false positive': 0.061538461538461542,
#    'time': 42.87200403213501}},
#  'k = 4, n = 2': {'kernel_metric': {'auc': 0.57371764273912251,
#    'false negative': 0.995908625980225,
#    'false positive': 0.0,
#    'time': 22.273530960083008},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.4854738712310791},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.3269410133361816}},
#  'k = 4, n = 20': {'kernel_metric': {'auc': 0.98512313462194134,
#    'false negative': 0.12308216842823048,
#    'false positive': 0.0061538461538461538,
#    'time': 30.417438983917236},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2647669315338135},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 50.455365896224976}},
#  'k = 4, n = 23': {'kernel_metric': {'auc': 0.79506097720894853,
#    'false negative': 0.13672008182748038,
#    'false positive': 0.64000000000000001,
#    'time': 31.812866926193237},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.368117094039917},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 63.20260286331177}},
#  'k = 4, n = 26': {'kernel_metric': {'auc': 0.78747829735896568,
#    'false negative': 0.10637572451414934,
#    'false positive': 0.75692307692307692,
#    'time': 33.36958408355713},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4851369857788086},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 71.74658393859863}},
#  'k = 4, n = 29': {'kernel_metric': {'auc': 0.28948254609352464,
#    'false negative': 0.11455847255369929,
#    'false positive': 1.0,
#    'time': 34.6576828956604},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.652022123336792},
#   'validate_classifier_by_random_points': {'auc': 0.15742138529728028,
#    'false negative': 0.11387657688373679,
#    'false positive': 1.0,
#    'time': 79.9269449710846}},
#  'k = 4, n = 5': {'kernel_metric': {'auc': 0.99989089669280595,
#    'false negative': 0.94817592908285031,
#    'false positive': 0.0,
#    'time': 23.4622859954834},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6572551727294922},
#   'validate_classifier_by_random_points': {'auc': 0.99464292270974852,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.004418134689331}},
#  'k = 4, n = 8': {'kernel_metric': {'auc': 0.99995279183823338,
#    'false negative': 0.062734401636549614,
#    'false positive': 0.0,
#    'time': 24.786741971969604},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7517788410186768},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.0081148147583}},
#  'k = 5, n = 11': {'kernel_metric': {'auc': 0.99899813790028591,
#    'false negative': 0.16331401295601772,
#    'false positive': 0.0,
#    'time': 26.163032054901123},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8492469787597656},
#   'validate_classifier_by_random_points': {'auc': 0.91491830365338722,
#    'false negative': 0.15649505625639276,
#    'false positive': 0.12615384615384614,
#    'time': 19.093822956085205}},
#  'k = 5, n = 14': {'kernel_metric': {'auc': 0.99837603923522777,
#    'false negative': 0.18888510057961133,
#    'false positive': 0.0,
#    'time': 27.594731092453003},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9705522060394287},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.623488903045654}},
#  'k = 5, n = 17': {'kernel_metric': {'auc': 0.99749377114532245,
#    'false negative': 0.074326628025912042,
#    'false positive': 0.0,
#    'time': 28.968544006347656},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1106820106506348},
#   'validate_classifier_by_random_points': {'auc': 0.78443179731962553,
#    'false negative': 0.012956017729287419,
#    'false positive': 1.0,
#    'time': 41.924850940704346}},
#  'k = 5, n = 2': {'kernel_metric': {'auc': 0.87636654514936141,
#    'false negative': 0.97067848619161268,
#    'false positive': 0.0,
#    'time': 22.161307096481323},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5121300220489502},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.7454490661621094}},
#  'k = 5, n = 20': {'kernel_metric': {'auc': 0.99127068635421856,
#    'false negative': 0.092737811114899427,
#    'false positive': 0.0030769230769230769,
#    'time': 30.369391918182373},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2796909809112549},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 57.03556513786316}},
#  'k = 5, n = 23': {'kernel_metric': {'auc': 0.87782213013716592,
#    'false negative': 0.10910330719399931,
#    'false positive': 0.4276923076923077,
#    'time': 31.821937799453735},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3309168815612793},
#   'validate_classifier_by_random_points': {'auc': 0.67336358152587272,
#    'false negative': 0.082168428230480733,
#    'false positive': 0.99076923076923074,
#    'time': 56.74211001396179}},
#  'k = 5, n = 26': {'kernel_metric': {'auc': 0.60376301502793162,
#    'false negative': 0.29253324241391065,
#    'false positive': 0.74769230769230766,
#    'time': 33.24943804740906},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.5050289630889893},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 66.10787606239319}},
#  'k = 5, n = 29': {'kernel_metric': {'auc': 0.28517296545936166,
#    'false negative': 0.10773951585407433,
#    'false positive': 1.0,
#    'time': 37.33759689331055},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6656880378723145},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 76.96790885925293}},
#  'k = 5, n = 5': {'kernel_metric': {'auc': 0.99462771119095705,
#    'false negative': 0.67200818274803953,
#    'false positive': 0.0,
#    'time': 23.441390991210938},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6481430530548096},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.790633916854858}},
#  'k = 5, n = 8': {'kernel_metric': {'auc': 0.99993285950326527,
#    'false negative': 0.29253324241391065,
#    'false positive': 0.0,
#    'time': 24.756659030914307},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7584118843078613},
#   'validate_classifier_by_random_points': {'auc': 0.98248996826562474,
#    'false negative': 0.15717695192635528,
#    'false positive': 0.0061538461538461538,
#    'time': 12.276003122329712}},
#  'k = 6, n = 11': {'kernel_metric': {'auc': 0.99849721901563626,
#    'false negative': 0.29399727148703958,
#    'false positive': 0.0,
#    'time': 30.12816596031189},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8746449947357178},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 21.03626012802124}},
#  'k = 6, n = 14': {'kernel_metric': {'auc': 0.99632070521565741,
#    'false negative': 0.12073669849931787,
#    'false positive': 0.0030769230769230769,
#    'time': 31.531695127487183},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.026474952697754},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 38.20154118537903}},
#  'k = 6, n = 17': {'kernel_metric': {'auc': 0.9865463322489243,
#    'false negative': 0.16541609822646658,
#    'false positive': 0.0030769230769230769,
#    'time': 30.31019616127014},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1299448013305664},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 43.30372595787048}},
#  'k = 6, n = 2': {'kernel_metric': {'auc': 0.69321282401091411,
#    'false negative': 0.98908594815825379,
#    'false positive': 0.0,
#    'time': 23.80334186553955},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5472280979156494},
#   'validate_classifier_by_random_points': {'auc': 0.50579809004092768,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.542083978652954}},
#  'k = 6, n = 20': {'kernel_metric': {'auc': 0.983595340539406,
#    'false negative': 0.14699863574351979,
#    'false positive': 0.0030769230769230769,
#    'time': 30.45055603981018},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2345390319824219},
#   'validate_classifier_by_random_points': {'auc': 0.67289747087837126,
#    'false negative': 0.36118690313778989,
#    'false positive': 0.35384615384615387,
#    'time': 56.60661578178406}},
#  'k = 6, n = 23': {'kernel_metric': {'auc': 0.84469514114807431,
#    'false negative': 0.11732605729877217,
#    'false positive': 0.5476923076923077,
#    'time': 31.774163961410522},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3353910446166992},
#   'validate_classifier_by_random_points': {'auc': 0.58628922237380632,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 60.097919940948486}},
#  'k = 6, n = 26': {'kernel_metric': {'auc': 0.83428166649176205,
#    'false negative': 0.093110504774897684,
#    'false positive': 0.66153846153846152,
#    'time': 36.65003299713135},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.7148830890655518},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 74.20869207382202}},
#  'k = 6, n = 29': {'kernel_metric': {'auc': 0.26123412740056667,
#    'false negative': 0.18860845839017734,
#    'false positive': 1.0,
#    'time': 35.171618938446045},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.701624870300293},
#   'validate_classifier_by_random_points': {'auc': 0.11699653688739636,
#    'false negative': 0.17394270122783084,
#    'false positive': 1.0,
#    'time': 72.68038892745972}},
#  'k = 6, n = 5': {'kernel_metric': {'auc': 0.99987826634484211,
#    'false negative': 0.98976807639836284,
#    'false positive': 0.0,
#    'time': 27.054847955703735},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.0873210430145264},
#   'validate_classifier_by_random_points': {'auc': 0.99882254171476548,
#    'false negative': 0.15620736698499318,
#    'false positive': 0.0030769230769230769,
#    'time': 8.653282880783081}},
#  'k = 6, n = 8': {'kernel_metric': {'auc': 0.99994752859691471,
#    'false negative': 0.42974079126875853,
#    'false positive': 0.0,
#    'time': 27.254394054412842},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7774841785430908},
#   'validate_classifier_by_random_points': {'auc': 0.98777101479693552,
#    'false negative': 0.96487039563437926,
#    'false positive': 0.0,
#    'time': 14.529525995254517}},
#  'k = 7, n = 11': {'kernel_metric': {'auc': 0.99971150567809275,
#    'false negative': 0.34401636549607911,
#    'false positive': 0.0,
#    'time': 27.64627981185913},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9983630180358887},
#   'validate_classifier_by_random_points': {'auc': 0.97651761126701464,
#    'false negative': 0.040231844527787247,
#    'false positive': 0.14769230769230771,
#    'time': 18.902003049850464}},
#  'k = 7, n = 14': {'kernel_metric': {'auc': 0.99662619003907793,
#    'false negative': 0.25059665871121717,
#    'false positive': 0.0,
#    'time': 29.7913339138031},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.045985221862793},
#   'validate_classifier_by_random_points': {'auc': 0.90843085315639016,
#    'false negative': 0.19434026593931128,
#    'false positive': 0.080000000000000002,
#    'time': 26.256207942962646}},
#  'k = 7, n = 17': {'kernel_metric': {'auc': 0.99296073854546407,
#    'false negative': 0.11728605523354926,
#    'false positive': 0.0030769230769230769,
#    'time': 30.8521728515625},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1525418758392334},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 39.29341006278992}},
#  'k = 7, n = 2': {'kernel_metric': {'auc': 0.73849353510451365,
#    'false negative': 0.98840777361063759,
#    'false positive': 0.0030769230769230769,
#    'time': 22.450223922729492},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5143311023712158},
#   'validate_classifier_by_random_points': {'auc': 0.95091400246531521,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.760694980621338}},
#  'k = 7, n = 20': {'kernel_metric': {'auc': 0.92156626190039059,
#    'false negative': 0.33549266962154789,
#    'false positive': 0.015384615384615385,
#    'time': 31.16892719268799},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3140671253204346},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 55.10951018333435}},
#  'k = 7, n = 23': {'kernel_metric': {'auc': 0.83663563167143118,
#    'false negative': 0.10535288100920559,
#    'false positive': 0.62769230769230766,
#    'time': 32.16751790046692},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3796288967132568},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 64.34797191619873}},
#  'k = 7, n = 26': {'kernel_metric': {'auc': 0.77247239633874476,
#    'false negative': 0.15785884759631777,
#    'false positive': 0.62461538461538457,
#    'time': 34.44410300254822},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.5001349449157715},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 73.41120314598083}},
#  'k = 7, n = 29': {'kernel_metric': {'auc': 0.38422827768889822,
#    'false negative': 0.1189907944084555,
#    'false positive': 1.0,
#    'time': 38.31997609138489},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 2.015679121017456},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 80.69133400917053}},
#  'k = 7, n = 5': {'kernel_metric': {'auc': 0.99930236827611529,
#    'false negative': 0.96863279918172518,
#    'false positive': 0.0,
#    'time': 25.232455015182495},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6410720348358154},
#   'validate_classifier_by_random_points': {'auc': 0.99883553200975639,
#    'false negative': 0.39618138424821003,
#    'false positive': 0.0,
#    'time': 8.580595016479492}},
#  'k = 7, n = 8': {'kernel_metric': {'auc': 0.99201132995882413,
#    'false negative': 0.5993862938970338,
#    'false positive': 0.0,
#    'time': 26.684711933135986},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7701451778411865},
#   'validate_classifier_by_random_points': {'auc': 0.50051142175247187,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 12.912997961044312}},
#  'k = 8, n = 11': {'kernel_metric': {'auc': 0.99988879855228308,
#    'false negative': 0.068530514831230821,
#    'false positive': 0.0,
#    'time': 26.33119010925293},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8754041194915771},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 22.437227964401245}},
#  'k = 8, n = 14': {'kernel_metric': {'auc': 0.9983445671273834,
#    'false negative': 0.13467439481759291,
#    'false positive': 0.0,
#    'time': 27.641221046447754},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.9543890953063965},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 27.698495864868164}},
#  'k = 8, n = 17': {'kernel_metric': {'auc': 0.98342888614964985,
#    'false negative': 0.18547562222979885,
#    'false positive': 0.0,
#    'time': 30.3855938911438},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1742300987243652},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 44.72533202171326}},
#  'k = 8, n = 2': {'kernel_metric': {'auc': 0.97727503999580378,
#    'false negative': 0.81316058643027622,
#    'false positive': 0.0092307692307692316,
#    'time': 24.933521032333374},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8284919261932373},
#   'validate_classifier_by_random_points': {'auc': 0.99392273597524183,
#    'false negative': 0.015342652574156155,
#    'false positive': 0.040000000000000001,
#    'time': 3.9181480407714844}},
#  'k = 8, n = 20': {'kernel_metric': {'auc': 0.9633360434315088,
#    'false negative': 0.27139447664507332,
#    'false positive': 0.0030769230769230769,
#    'time': 30.66134786605835},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3397960662841797},
#   'validate_classifier_by_random_points': {'auc': 0.98228225235385147,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 55.649701833724976}},
#  'k = 8, n = 23': {'kernel_metric': {'auc': 0.80105641375331105,
#    'false negative': 0.17354244800545515,
#    'false positive': 0.54153846153846152,
#    'time': 31.948695182800293},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.369638204574585},
#   'validate_classifier_by_random_points': {'auc': 0.37035327441055366,
#    'false negative': 0.27719058983975453,
#    'false positive': 1.0,
#    'time': 56.825589179992676}},
#  'k = 8, n = 26': {'kernel_metric': {'auc': 0.80011644679902438,
#    'false negative': 0.15138083873167404,
#    'false positive': 0.60307692307692307,
#    'time': 33.37451410293579},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4841699600219727},
#   'validate_classifier_by_random_points': {'auc': 0.29289622072438304,
#    'false negative': 0.089669280600068194,
#    'false positive': 1.0,
#    'time': 74.45174193382263}},
#  'k = 8, n = 29': {'kernel_metric': {'auc': 0.31234493430197491,
#    'false negative': 0.1131946812137743,
#    'false positive': 1.0,
#    'time': 35.67700505256653},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.644507884979248},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 77.80196905136108}},
#  'k = 8, n = 5': {'kernel_metric': {'auc': 0.99975137034802897,
#    'false negative': 0.70576201841118313,
#    'false positive': 0.0,
#    'time': 23.58243203163147},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.648223876953125},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 11.43534779548645}},
#  'k = 8, n = 8': {'kernel_metric': {'auc': 0.99990768181698975,
#    'false negative': 0.1418342993521991,
#    'false positive': 0.0,
#    'time': 26.434710025787354},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7633650302886963},
#   'validate_classifier_by_random_points': {'auc': 0.98682367751580169,
#    'false negative': 0.11660415956358677,
#    'false positive': 0.027692307692307693,
#    'time': 14.13995885848999}},
#  'k = 9, n = 11': {'kernel_metric': {'auc': 0.9978048972521848,
#    'false negative': 0.2940975776185602,
#    'false positive': 0.0,
#    'time': 26.8935649394989},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8631870746612549},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 19.00152015686035}},
#  'k = 9, n = 14': {'kernel_metric': {'auc': 0.9988158412723408,
#    'false negative': 0.16956670078471511,
#    'false positive': 0.0,
#    'time': 28.035371780395508},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1220171451568604},
#   'validate_classifier_by_random_points': {'auc': 0.90854578379655149,
#    'false negative': 0.972705561241897,
#    'false positive': 0.0,
#    'time': 31.806945085525513}},
#  'k = 9, n = 17': {'kernel_metric': {'auc': 0.98528304857885196,
#    'false negative': 0.12555441828727396,
#    'false positive': 0.015384615384615385,
#    'time': 29.79150080680847},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.3413491249084473},
#   'validate_classifier_by_random_points': {'auc': 0.84976930950318874,
#    'false negative': 0.088024564994882287,
#    'false positive': 0.70153846153846156,
#    'time': 39.67399597167969}},
#  'k = 9, n = 2': {'kernel_metric': {'auc': 0.9871222738367057,
#    'false negative': 0.67621972023200272,
#    'false positive': 0.0030769230769230769,
#    'time': 22.97272801399231},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.4961678981781006},
#   'validate_classifier_by_random_points': {'auc': 0.91104322494291778,
#    'false negative': 0.96554077106789493,
#    'false positive': 0.0,
#    'time': 3.8251848220825195}},
#  'k = 9, n = 20': {'kernel_metric': {'auc': 0.98855838122982431,
#    'false negative': 0.095871716137836918,
#    'false positive': 0.012307692307692308,
#    'time': 30.513121843338013},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2263860702514648},
#   'validate_classifier_by_random_points': {'auc': 0.98855838122982431,
#    'false negative': 0.095871716137836918,
#    'false positive': 0.012307692307692308,
#    'time': 49.91491913795471}},
#  'k = 9, n = 23': {'kernel_metric': {'auc': 0.81975382515812412,
#    'false negative': 0.17946093483452746,
#    'false positive': 0.40307692307692305,
#    'time': 32.990727186203},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.398094892501831},
#   'validate_classifier_by_random_points': {'auc': 0.93219116604991725,
#    'false negative': 0.44558171272603209,
#    'false positive': 0.0061538461538461538,
#    'time': 58.283246994018555}},
#  'k = 9, n = 26': {'kernel_metric': {'auc': 0.75050783402881671,
#    'false negative': 0.16717843739338109,
#    'false positive': 0.70461538461538464,
#    'time': 34.88740396499634},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.4746119976043701},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 71.13645195960999}},
#  'k = 9, n = 29': {'kernel_metric': {'auc': 0.33406398446316565,
#    'false negative': 0.11770726714431934,
#    'false positive': 1.0,
#    'time': 34.75455188751221},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.6803019046783447},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 79.36070799827576}},
#  'k = 9, n = 5': {'kernel_metric': {'auc': 0.9909655407710678,
#    'false negative': 0.99454111224837938,
#    'false positive': 0.0,
#    'time': 25.542551040649414},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6496241092681885},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.974088907241821}},
#  'k = 9, n = 8': {'kernel_metric': {'auc': 0.9997700968427683,
#    'false negative': 0.58955987717502556,
#    'false positive': 0.0,
#    'time': 26.559961080551147},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7761919498443604},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 17.268253087997437}}}

# %%
results = {}
for data_set in os.listdir('./csv_data_set/'):
    data = pd.read_csv('./csv_data_set/{}'.format(data_set))
    try:
        results[data_set] =  process_data_set(data)
    except:
        pass
# Out:
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (101, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (101, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (101, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (102, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (102, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (105, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (111, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (118, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (129, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (167, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (232, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (335, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (481, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (662, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (753, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (768, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (778, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (778, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (779, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (780, 57)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (3, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (15, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (15, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (15, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (14, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (15, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (7, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (16, 33)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (23, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (24, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (35, 4)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (40, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (89, 8)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (2, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (2, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 21)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 256)
# ...
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (100, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (102, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (103, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (104, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (108, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (121, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (133, 1024)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1e-10, kernel='rbf',
#    max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.5595479226995335e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=6.5512855685954954e-10, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.67683293681101e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.291934260128778e-09,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.0985411419875573e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.8117686979742307e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.1968567300115293e-08, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.8420699693267165e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=4.7148663634573897e-07, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=1.2067926406393288e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=3.0888435964774849e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=7.9060432109077017e-06, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=2.0235896477251556e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=5.1794746792312125e-05, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00013257113655901109, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3,
#    gamma=0.00033932217718953299, kernel='rbf', max_iter=-1,
#    random_state=None, shrinking=True, tol=0.001, verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.000868511373751352,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0022229964825261957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.0056898660290183051,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.014563484775012445,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.037275937203149381,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.095409547634999634,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.24420530945486549,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=0.62505519252739761,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1.5998587196060574,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=4.0949150623804194,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10.481131341546874,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=26.826957952797272,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=68.664884500429977,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=175.75106248547965,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=449.84326689694529,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1151.3953993264481,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2947.0517025518097,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=7543.1200633546077,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=19306.977288832535,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=49417.13361323838,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=126485.52168552957,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=323745.75428176532,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=828642.7728546859,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=2120950.8879201924,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=5428675.4393238593,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=13894954.94373136,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=35564803.062231213,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=91029817.799152642,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=232995181.05153814,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=596362331.65946615,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=1526417967.1752365,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=3906939937.0546207,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)
# SVDD(C=0.01, cache_size=200, coef0=0.0, degree=3, gamma=10000000000.0,
#    kernel='rbf', max_iter=-1, random_state=None, shrinking=True, tol=0.001,
#    verbose=False)
# (75, 3)

# %%
results
# Out:
# {'Abalone class 1-8.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7873198986053467},
#   'kernel_metric': {'auc': 0.85382155158274553,
#    'false negative': 0.27505330490405117,
#    'false positive': 0.15384615384615385,
#    'time': 0.651655912399292},
#   'support_vectors_metric': {'auc': 0.7643103165491224,
#    'false negative': 0.040511727078891259,
#    'false positive': 0.59615384615384615,
#    'time': 0.6104202270507812},
#   'validate_classifier_by_random_points': {'auc': 0.86189929473511562,
#    'false negative': 0.41577825159914711,
#    'false positive': 0.096153846153846159,
#    'time': 12.726355075836182}},
#  'Abalone class 11-29.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.2486910820007324},
#   'kernel_metric': {'auc': 0.76062788694903316,
#    'false negative': 0.21576763485477179,
#    'false positive': 0.45283018867924529,
#    'time': 0.6762290000915527},
#   'support_vectors_metric': {'auc': 0.71197056290613014,
#    'false negative': 0.1078838174273859,
#    'false positive': 0.660377358490566,
#    'time': 0.9074897766113281},
#   'validate_classifier_by_random_points': {'auc': 0.66945901510999761,
#    'false negative': 0.37344398340248963,
#    'false positive': 0.41509433962264153,
#    'time': 13.177358150482178}},
#  'Abalone class 9-10.csv': {'combinatorial_dimension_metric': {'auc': 0.47190985237632471,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7190289497375488},
#   'kernel_metric': {'auc': 0.61520662686843453,
#    'false negative': 0.11337868480725624,
#    'false positive': 0.7142857142857143,
#    'time': 0.5367300510406494},
#   'support_vectors_metric': {'auc': 0.61678004535147402,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5239870548248291},
#   'validate_classifier_by_random_points': {'auc': 0.6094682771067611,
#    'false negative': 0.39229024943310659,
#    'false positive': 0.46938775510204084,
#    'time': 12.140162944793701}},
#  'Breast Wisconsin (targetcl. benign).csv': {'combinatorial_dimension_metric': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 0.1439039707183838},
#   'kernel_metric': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 0.06629085540771484},
#   'support_vectors_metric': {'auc': 0.93379934210526316,
#    'false negative': 0.15131578947368421,
#    'false positive': 0.0625,
#    'time': 0.11478900909423828},
#   'validate_classifier_by_random_points': {'auc': 0.93379934210526316,
#    'false negative': 0.15131578947368421,
#    'false positive': 0.0625,
#    'time': 8.178552865982056}},
#  'Cancer wpbc ret.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.029529094696044922},
#   'kernel_metric': {'auc': 0.26666666666666666,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.009222984313964844},
#   'support_vectors_metric': {'auc': 0.26666666666666666,
#    'false negative': 0.26666666666666666,
#    'false positive': 1.0,
#    'time': 0.024927139282226562},
#   'validate_classifier_by_random_points': {'auc': 0.59999999999999998,
#    'false negative': 0.26666666666666666,
#    'false positive': 1.0,
#    'time': 3.3635480403900146}},
#  'Concordia (targetcl. 0).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8614959716796875},
#   'kernel_metric': {'auc': 0.96240601503759382,
#    'false negative': 0.43609022556390975,
#    'false positive': 0.0,
#    'time': 0.3305089473724365},
#   'support_vectors_metric': {'auc': 0.91621911922663801,
#    'false negative': 0.81954887218045114,
#    'false positive': 0.0,
#    'time': 0.6131231784820557},
#   'validate_classifier_by_random_points': {'auc': 0.972610096670247,
#    'false negative': 0.93984962406015038,
#    'false positive': 0.0,
#    'time': 71.02970218658447}},
#  'Concordia (targetcl. 1).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.029360055923462},
#   'kernel_metric': {'auc': 0.99194414607948445,
#    'false negative': 0.64661654135338342,
#    'false positive': 0.0,
#    'time': 1.7684428691864014},
#   'support_vectors_metric': {'auc': 0.93125671321160031,
#    'false negative': 0.81203007518796988,
#    'false positive': 0.0,
#    'time': 2.216815948486328},
#   'validate_classifier_by_random_points': {'auc': 0.99731471535982819,
#    'false negative': 0.98496240601503759,
#    'false positive': 0.0,
#    'time': 273.2444808483124}},
#  'Concordia (targetcl. 2).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8024508953094482},
#   'kernel_metric': {'auc': 0.84962406015037606,
#    'false negative': 0.45864661654135336,
#    'false positive': 0.071428571428571425,
#    'time': 0.3261849880218506},
#   'support_vectors_metric': {'auc': 0.61331901181525239,
#    'false negative': 0.0,
#    'false positive': 1.0,
#    'time': 0.7401211261749268},
#   'validate_classifier_by_random_points': {'auc': 0.90440386680988183,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 69.96066689491272}},
#  'Concordia (targetcl. 3).csv': {'combinatorial_dimension_metric': {'auc': 0.70381310418904397,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.1999480724334717},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.758946180343628},
#   'support_vectors_metric': {'auc': 0.89419978517722876,
#    'false negative': 0.31578947368421051,
#    'false positive': 0.071428571428571425,
#    'time': 2.2228660583496094},
#   'validate_classifier_by_random_points': {'auc': 0.89097744360902253,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 283.79975605010986}},
#  'Concordia (targetcl. 4).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8806068897247314},
#   'kernel_metric': {'auc': 0.91944146079484423,
#    'false negative': 0.82706766917293228,
#    'false positive': 0.0,
#    'time': 0.34992504119873047},
#   'support_vectors_metric': {'auc': 0.95220193340494097,
#    'false negative': 0.11278195488721804,
#    'false positive': 0.14285714285714285,
#    'time': 0.6120741367340088},
#   'validate_classifier_by_random_points': {'auc': 0.87271750805585391,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 81.84814500808716}},
#  'Concordia (targetcl. 5).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1036012172698975},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.3291490077972412},
#   'support_vectors_metric': {'auc': 0.85177228786251336,
#    'false negative': 0.0,
#    'false positive': 1.0,
#    'time': 0.6748979091644287},
#   'validate_classifier_by_random_points': {'auc': 0.9291084854994629,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 73.47562909126282}},
#  'Concordia (targetcl. 6).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.9078760147094727},
#   'kernel_metric': {'auc': 0.88131041890440387,
#    'false negative': 0.94736842105263153,
#    'false positive': 0.0,
#    'time': 1.8916609287261963},
#   'support_vectors_metric': {'auc': 0.71643394199785182,
#    'false negative': 0.95488721804511278,
#    'false positive': 0.0,
#    'time': 2.7204291820526123},
#   'validate_classifier_by_random_points': {'auc': 0.82062298603651973,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 289.649276971817}},
#  'Concordia (targetcl. 7).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.179908037185669},
#   'kernel_metric': {'auc': 0.96885069817400638,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 1.772665023803711},
#   'support_vectors_metric': {'auc': 0.93877551020408156,
#    'false negative': 0.81203007518796988,
#    'false positive': 0.0,
#    'time': 2.218590021133423},
#   'validate_classifier_by_random_points': {'auc': 0.94683136412459712,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 291.85811281204224}},
#  'Concordia (targetcl. 8).csv': {'combinatorial_dimension_metric': {'auc': 0.65413533834586468,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.1259219646453857},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.3294191360473633},
#   'support_vectors_metric': {'auc': 0.63963480128893668,
#    'false negative': 0.0075187969924812026,
#    'false positive': 1.0,
#    'time': 0.794187068939209},
#   'validate_classifier_by_random_points': {'auc': 0.79108485499462944,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 72.51701998710632}},
#  'Concordia (targetcl. 9).csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.8705129623413086},
#   'kernel_metric': {'auc': 0.94575725026852842,
#    'false negative': 0.32330827067669171,
#    'false positive': 0.0,
#    'time': 0.33196282386779785},
#   'support_vectors_metric': {'auc': 0.83619763694951654,
#    'false negative': 0.075187969924812026,
#    'false positive': 0.5,
#    'time': 0.610278844833374},
#   'validate_classifier_by_random_points': {'auc': 0.94790547798066593,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 72.05411005020142}},
#  'Delft pump 5x3.csv': {'combinatorial_dimension_metric': {'auc': 0.51200000000000001,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.2913200855255127},
#   'kernel_metric': {'auc': 0.51815384615384619,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.10275697708129883},
#   'support_vectors_metric': {'auc': 0.49107692307692308,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.20577096939086914},
#   'validate_classifier_by_random_points': {'auc': 0.51630769230769225,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 16.75829005241394}},
#  'Diabetes (targetcl. present).csv': {'combinatorial_dimension_metric': {'auc': 0.50970548862115128,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.1887040138244629},
#   'kernel_metric': {'auc': 0.54317269076305219,
#    'false negative': 0.39156626506024095,
#    'false positive': 0.5,
#    'time': 0.07467794418334961},
#   'support_vectors_metric': {'auc': 0.67168674698795183,
#    'false negative': 0.40361445783132532,
#    'false positive': 0.3888888888888889,
#    'time': 0.13720202445983887},
#   'validate_classifier_by_random_points': {'auc': 0.51137884872824624,
#    'false negative': 0.72891566265060237,
#    'false positive': 0.3888888888888889,
#    'time': 7.896346092224121}},
#  'Heart Cleveland.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.05471396446228027},
#   'kernel_metric': {'auc': 0.44444444444444442,
#    'false negative': 0.68888888888888888,
#    'false positive': 0.20000000000000001,
#    'time': 0.014174938201904297},
#   'support_vectors_metric': {'auc': 0.50222222222222224,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.04230213165283203},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 4.79967999458313}},
#  'Pageblocks text.csv': {'combinatorial_dimension_metric': {'auc': 0.49768306800271345,
#    'false negative': 0.97923029932803907,
#    'false positive': 0.082872928176795577,
#    'time': 9.78230905532837},
#   'kernel_metric': {'auc': 0.54630320252989395,
#    'false negative': 0.83200977397678677,
#    'false positive': 0.082872928176795577,
#    'time': 7.566370010375977},
#   'support_vectors_metric': {'auc': 0.59450483805100962,
#    'false negative': 0.55956017104459377,
#    'false positive': 0.36464088397790057,
#    'time': 6.802126169204712},
#   'validate_classifier_by_random_points': {'auc': 0.54630320252989395,
#    'false negative': 0.83200977397678677,
#    'false positive': 0.082872928176795577,
#    'time': 44.448997020721436}},
#  'Spambase other.csv': {'combinatorial_dimension_metric': {'auc': 0.51345532831001073,
#    'false negative': 0.9741657696447793,
#    'false positive': 0.0,
#    'time': 6.278210878372192},
#   'kernel_metric': {'auc': 0.51722282023681376,
#    'false negative': 0.9806243272335845,
#    'false positive': 0.0,
#    'time': 5.152719974517822},
#   'support_vectors_metric': {'auc': 0.39375254736798104,
#    'false negative': 0.073196986006458561,
#    'false positive': 0.81553398058252424,
#    'time': 4.6132190227508545},
#   'validate_classifier_by_random_points': {'auc': 0.78078526863628295,
#    'false negative': 0.75134553283100103,
#    'false positive': 0.019417475728155338,
#    'time': 58.97225284576416}},
#  'Spambase spam.csv': {'combinatorial_dimension_metric': {'auc': 0.54470198675496684,
#    'false negative': 0.9668874172185431,
#    'false positive': 0.0,
#    'time': 3.522922992706299},
#   'kernel_metric': {'auc': 0.40963230206582979,
#    'false negative': 0.35264900662251658,
#    'false positive': 0.83582089552238803,
#    'time': 2.1336660385131836},
#   'support_vectors_metric': {'auc': 0.76215775427498278,
#    'false negative': 0.064569536423841056,
#    'false positive': 0.73134328358208955,
#    'time': 2.4738259315490723},
#   'validate_classifier_by_random_points': {'auc': 0.39033310269842836,
#    'false negative': 0.46026490066225167,
#    'false positive': 0.62686567164179108,
#    'time': 41.932493925094604}},
#  'Spectf 1.csv': {'combinatorial_dimension_metric': {'auc': 0.33333333333333337,
#    'false negative': 0.61904761904761907,
#    'false positive': 0.66666666666666663,
#    'time': 0.1170341968536377},
#   'kernel_metric': {'auc': 0.51587301587301582,
#    'false negative': 0.32142857142857145,
#    'false positive': 0.66666666666666663,
#    'time': 0.042819976806640625},
#   'support_vectors_metric': {'auc': 0.73809523809523814,
#    'false negative': 0.5714285714285714,
#    'false positive': 0.0,
#    'time': 0.06953096389770508},
#   'validate_classifier_by_random_points': {'auc': 0.51587301587301582,
#    'false negative': 0.32142857142857145,
#    'false positive': 0.66666666666666663,
#    'time': 16.114084005355835}},
#  'Thyriod hyperfunction.csv': {'combinatorial_dimension_metric': {'auc': 0.58730158730158732,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.05561208724975586},
#   'kernel_metric': {'auc': 0.69387755102040816,
#    'false negative': 0.5714285714285714,
#    'false positive': 0.14285714285714285,
#    'time': 0.021553993225097656},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.04235386848449707},
#   'validate_classifier_by_random_points': {'auc': 0.67573696145124718,
#    'false negative': 0.66666666666666663,
#    'false positive': 0.0,
#    'time': 6.0745768547058105}},
#  'Waveform 0.csv': {'combinatorial_dimension_metric': {'auc': 0.75818181818181818,
#    'false negative': 0.96999999999999997,
#    'false positive': 0.0,
#    'time': 0.10802698135375977},
#   'kernel_metric': {'auc': 0.75818181818181818,
#    'false negative': 0.54000000000000004,
#    'false positive': 0.18181818181818182,
#    'time': 0.039726972579956055},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.07403922080993652},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 6.9642181396484375}}}

# %%
import pickle as pkl

# %%
pkl.dump(results, open('realWorldResults.pkl', 'wb'))

# %%
pkl.load(open('realWorldResults.pkl'))
# Out:
# {'Abalone class 1-8.csv': {'combinatorial_dimension_metric': {'auc': 0.79200836476955871,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.1817920207977295},
#   'kernel_metric': {'auc': 0.82159258651795963,
#    'false negative': 0.27505330490405117,
#    'false positive': 0.25,
#    'time': 0.634497880935669},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.14460206031799316},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.0374839305877686}},
#  'Abalone class 11-29.csv': {'combinatorial_dimension_metric': {'auc': 0.43419713458075626,
#    'false negative': 0.96680497925311204,
#    'false positive': 0.075471698113207544,
#    'time': 0.17970585823059082},
#   'kernel_metric': {'auc': 0.73995928912549913,
#    'false negative': 0.21576763485477179,
#    'false positive': 0.47169811320754718,
#    'time': 0.6787641048431396},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.14283299446105957},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 4.8495869636535645}},
#  'Abalone class 9-10.csv': {'combinatorial_dimension_metric': {'auc': 0.64574945624508306,
#    'false negative': 0.68707482993197277,
#    'false positive': 0.14285714285714285,
#    'time': 0.17295193672180176},
#   'kernel_metric': {'auc': 0.70725160812624377,
#    'false negative': 0.11337868480725624,
#    'false positive': 0.61224489795918369,
#    'time': 0.5593130588531494},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.14073491096496582},
#   'validate_classifier_by_random_points': {'auc': 0.70725160812624377,
#    'false negative': 0.11337868480725624,
#    'false positive': 0.61224489795918369,
#    'time': 4.840329170227051}},
#  'Balance-scale left.csv': {'combinatorial_dimension_metric': {'auc': 0.36927083333333333,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.04765605926513672},
#   'kernel_metric': {'auc': 0.35833333333333339,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.02788400650024414},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.017155885696411133},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 8.199494123458862}},
#  'Breast Wisconsin (targetcl. benign).csv': {'combinatorial_dimension_metric': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 0.07802200317382812},
#   'kernel_metric': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 0.06621885299682617},
#   'support_vectors_metric': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 0.04424405097961426},
#   'validate_classifier_by_random_points': {'auc': 0.75,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 5.710969924926758}},
#  'Cancer wpbc non-ret.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.03823709487915039},
#   'kernel_metric': {'auc': 0.49199999999999999,
#    'false negative': 0.81999999999999995,
#    'false positive': 0.20000000000000001,
#    'time': 0.01789402961730957},
#   'support_vectors_metric': {'auc': 0.48399999999999999,
#    'false negative': 0.14000000000000001,
#    'false positive': 1.0,
#    'time': 0.016424179077148438},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 4.45508599281311}},
#  'Concordia (targetcl. 0).csv': {'combinatorial_dimension_metric': {'auc': 0.9291084854994629,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6808619499206543},
#   'kernel_metric': {'auc': 0.94736842105263153,
#    'false negative': 0.43609022556390975,
#    'false positive': 0.0,
#    'time': 0.3308231830596924},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.48666906356811523},
#   'validate_classifier_by_random_points': {'auc': 0.91675617615467242,
#    'false negative': 0.63157894736842102,
#    'false positive': 0.0,
#    'time': 62.065739154815674}},
#  'Concordia (targetcl. 1).csv': {'combinatorial_dimension_metric': {'auc': 0.84962406015037595,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 2.4899518489837646},
#   'kernel_metric': {'auc': 0.98549946294307189,
#    'false negative': 0.64661654135338342,
#    'false positive': 0.0,
#    'time': 1.767502784729004},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.842405080795288},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 252.58479809761047}},
#  'Concordia (targetcl. 2).csv': {'combinatorial_dimension_metric': {'auc': 0.8437164339419978,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.7065949440002441},
#   'kernel_metric': {'auc': 0.68904403866809893,
#    'false negative': 0.45864661654135336,
#    'false positive': 0.14285714285714285,
#    'time': 0.3500840663909912},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.49339795112609863},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 66.17874884605408}},
#  'Concordia (targetcl. 3).csv': {'combinatorial_dimension_metric': {'auc': 0.84640171858216962,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 2.5714330673217773},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.7781720161437988},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.884016990661621},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 259.98040103912354}},
#  'Concordia (targetcl. 4).csv': {'combinatorial_dimension_metric': {'auc': 0.80290010741138562,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6642229557037354},
#   'kernel_metric': {'auc': 0.91783029001074112,
#    'false negative': 0.82706766917293228,
#    'false positive': 0.0,
#    'time': 0.3295619487762451},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.4778170585632324},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 65.95228409767151}},
#  'Concordia (targetcl. 5).csv': {'combinatorial_dimension_metric': {'auc': 0.7857142857142857,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.804365873336792},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.36922407150268555},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.5367791652679443},
#   'validate_classifier_by_random_points': {'auc': 0.90332975295381313,
#    'false negative': 0.24812030075187969,
#    'false positive': 0.071428571428571425,
#    'time': 70.65558314323425}},
#  'Concordia (targetcl. 6).csv': {'combinatorial_dimension_metric': {'auc': 0.91138560687432846,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 2.5985732078552246},
#   'kernel_metric': {'auc': 0.87486573576799131,
#    'false negative': 0.94736842105263153,
#    'false positive': 0.0,
#    'time': 1.8046538829803467},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.886841058731079},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 274.7008810043335}},
#  'Concordia (targetcl. 7).csv': {'combinatorial_dimension_metric': {'auc': 0.91890440386680994,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 2.5785770416259766},
#   'kernel_metric': {'auc': 0.95703544575725019,
#    'false negative': 0.78947368421052633,
#    'false positive': 0.0,
#    'time': 2.051496982574463},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 1.877302885055542},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 265.9369421005249}},
#  'Concordia (targetcl. 8).csv': {'combinatorial_dimension_metric': {'auc': 0.78517722878625129,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6605470180511475},
#   'kernel_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.3309190273284912},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.46614909172058105},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 64.20924091339111}},
#  'Concordia (targetcl. 9).csv': {'combinatorial_dimension_metric': {'auc': 0.96240601503759404,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6589260101318359},
#   'kernel_metric': {'auc': 0.93609022556390975,
#    'false negative': 0.32330827067669171,
#    'false positive': 0.071428571428571425,
#    'time': 0.33002400398254395},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.4680819511413574},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 63.39919185638428}},
#  'Delft pump 5x3 noisy.csv': {'combinatorial_dimension_metric': {'auc': 0.46527777777777779,
#    'false negative': 0.63888888888888884,
#    'false positive': 0.375,
#    'time': 0.10253000259399414},
#   'kernel_metric': {'auc': 0.50347222222222221,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.04938006401062012},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.05134701728820801},
#   'validate_classifier_by_random_points': {'auc': 0.46527777777777779,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 14.285053014755249}},
#  'Delft pump 5x3.csv': {'combinatorial_dimension_metric': {'auc': 0.39446153846153853,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.19981789588928223},
#   'kernel_metric': {'auc': 0.41353846153846152,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.1012721061706543},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.12996912002563477},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 12.554024934768677}},
#  'Diabetes (targetcl. present).csv': {'combinatorial_dimension_metric': {'auc': 0.60876840696117807,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.08258605003356934},
#   'kernel_metric': {'auc': 0.65394912985274434,
#    'false negative': 0.39156626506024095,
#    'false positive': 0.27777777777777779,
#    'time': 0.07594490051269531},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.050302982330322266},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 3.8816380500793457}},
#  'Ionosphere bad.csv': {'combinatorial_dimension_metric': {'auc': 0.38095238095238099,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.034155845642089844},
#   'kernel_metric': {'auc': 0.23809523809523808,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.016115903854370117},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.0174710750579834},
#   'validate_classifier_by_random_points': {'auc': 0.38095238095238099,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.168770790100098}},
#  'Liver 2.csv': {'combinatorial_dimension_metric': {'auc': 0.40476190476190477,
#    'false negative': 0.95454545454545459,
#    'false positive': 0.0,
#    'time': 0.028263092041015625},
#   'kernel_metric': {'auc': 0.44372294372294374,
#    'false negative': 0.60606060606060608,
#    'false positive': 0.2857142857142857,
#    'time': 0.018551111221313477},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.023025989532470703},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 4.53889012336731}},
#  'Pageblocks text.csv': {'combinatorial_dimension_metric': {'auc': 0.41476963992210525,
#    'false negative': 0.99205864386072085,
#    'false positive': 0.016574585635359115,
#    'time': 0.5027151107788086},
#   'kernel_metric': {'auc': 0.48811665322294862,
#    'false negative': 0.83200977397678677,
#    'false positive': 0.10497237569060773,
#    'time': 8.055866003036499},
#   'support_vectors_metric': {'auc': 0.49815387938453642,
#    'false negative': 0.99816737935247402,
#    'false positive': 0.0055248618784530384,
#    'time': 0.46614885330200195},
#   'validate_classifier_by_random_points': {'auc': 0.69221591848719366,
#    'false negative': 0.22785583384239463,
#    'false positive': 0.49723756906077349,
#    'time': 6.652259111404419}},
#  'Spambase other.csv': {'combinatorial_dimension_metric': {'auc': 0.60146101351280745,
#    'false negative': 0.061356297093649086,
#    'false positive': 0.72815533980582525,
#    'time': 1.1044540405273438},
#   'kernel_metric': {'auc': 0.51722282023681376,
#    'false negative': 0.9806243272335845,
#    'false positive': 0.0,
#    'time': 5.894158840179443},
#   'support_vectors_metric': {'auc': 0.51345532831001073,
#    'false negative': 0.9741657696447793,
#    'false positive': 0.0,
#    'time': 1.048828125},
#   'validate_classifier_by_random_points': {'auc': 0.77742535558644332,
#    'false negative': 0.99569429494079653,
#    'false positive': 0.0,
#    'time': 21.71971607208252}},
#  'Spambase spam.csv': {'combinatorial_dimension_metric': {'auc': 0.3796827122664822,
#    'false negative': 0.26655629139072845,
#    'false positive': 0.79104477611940294,
#    'time': 0.6903769969940186},
#   'kernel_metric': {'auc': 0.40286152021350208,
#    'false negative': 0.35264900662251658,
#    'false positive': 0.80597014925373134,
#    'time': 2.2153429985046387},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.6177639961242676},
#   'validate_classifier_by_random_points': {'auc': 0.5322847682119205,
#    'false negative': 0.9983443708609272,
#    'false positive': 0.0,
#    'time': 13.076341152191162}},
#  'Thyriod hyperfunction.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.03435492515563965},
#   'kernel_metric': {'auc': 0.40816326530612246,
#    'false negative': 0.5714285714285714,
#    'false positive': 0.7142857142857143,
#    'time': 0.021576881408691406},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.02435922622680664},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.651864051818848}},
#  'Vehicle bus.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.0317840576171875},
#   'kernel_metric': {'auc': 0.80555555555555558,
#    'false negative': 0.44444444444444442,
#    'false positive': 0.125,
#    'time': 0.024103164672851562},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.025374889373779297},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 5.877579927444458}},
#  'Waveform 1.csv': {'combinatorial_dimension_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.11504912376403809},
#   'kernel_metric': {'auc': 0.9054545454545454,
#    'false negative': 0.42999999999999999,
#    'false positive': 0.090909090909090912,
#    'time': 0.040483951568603516},
#   'support_vectors_metric': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 0.022242069244384766},
#   'validate_classifier_by_random_points': {'auc': 0.5,
#    'false negative': 1.0,
#    'false positive': 0.0,
#    'time': 7.507020950317383}}}

# %%
for key, value in results.items():
    print value['validate_classifier_by_random_points']
# Out:
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 68.87951302528381}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 12.977542877197266}
# {'false negative': 0.15040927694406547, 'auc': 0.99883618427956766, 'false positive': 0.0, 'time': 8.082266092300415}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 65.14672493934631}
# {'false negative': 0.10910330719399931, 'auc': 0.52097563534317715, 'false positive': 1.0, 'time': 52.07295298576355}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 62.086408853530884}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 74.37733006477356}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 13.040939092636108}
# {'false negative': 0.035458574838049775, 'auc': 0.99840646227281082, 'false positive': 0.0092307692307692316, 'time': 6.25279688835144}
# {'false negative': 0.10910330719399931, 'auc': 0.9962747515014817, 'false positive': 0.0092307692307692316, 'time': 2.9082159996032715}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 47.3726909160614}
# {'false negative': 0.10330719399931811, 'auc': 0.3279509035117627, 'false positive': 1.0, 'time': 80.80316495895386}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 71.07675886154175}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 62.850862979888916}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 64.63310885429382}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 28.176408052444458}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 44.67784094810486}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 23.267393112182617}
# {'false negative': 0.90862598022502561, 'auc': 0.086147551732277269, 'false positive': 0.56923076923076921, 'time': 80.60207200050354}
# {'false negative': 0.047424087342204026, 'auc': 0.9540561110673702, 'false positive': 0.3446153846153846, 'time': 29.803640127182007}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 53.91453695297241}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 59.221916913986206}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 56.53198289871216}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 25.79530906677246}
# {'false negative': 1.0, 'auc': 0.76544895868897234, 'false positive': 0.0, 'time': 41.82029414176941}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 27.263823986053467}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 3.6296660900115967}
# {'false negative': 0.092396863279918168, 'auc': 0.91273413936898429, 'false positive': 0.3446153846153846, 'time': 26.62477207183838}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 19.366806030273438}
# {'false negative': 0.2323439099283521, 'auc': 0.99964622208225073, 'false positive': 0.0, 'time': 7.762413024902344}
# {'false negative': 1.0, 'auc': 0.51160013647219382, 'false positive': 0.0, 'time': 3.6416878700256348}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 41.005757093429565}
# {'false negative': 0.037845209682918511, 'auc': 0.98876655564006422, 'false positive': 0.046153846153846156, 'time': 26.525898933410645}
# {'false negative': 0.25536992840095463, 'auc': 0.85929030396810824, 'false positive': 0.08615384615384615, 'time': 27.95777201652527}
# {'false negative': 0.98839986352780618, 'auc': 0.99999895021389396, 'false positive': 0.0, 'time': 12.014794111251831}
# {'false negative': 0.16160927378111148, 'auc': 0.71930551548689969, 'false positive': 0.85538461538461541, 'time': 41.056140184402466}
# {'false negative': 1.0, 'auc': 0.50034141345169003, 'false positive': 0.0, 'time': 3.616895914077759}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 7.3380210399627686}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 15.057613134384155}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 16.741719007492065}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 46.900567054748535}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 25.84789204597473}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 84.85003399848938}
# {'false negative': 0.066143879986362092, 'auc': 0.73984631120669297, 'false positive': 0.98153846153846158, 'time': 59.880187034606934}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 62.947635889053345}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 75.44936203956604}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 20.704966068267822}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 33.79115700721741}
# {'false negative': 0.15392491467576791, 'auc': 0.74203097925964812, 'false positive': 0.82461538461538464, 'time': 44.467989921569824}
# {'false negative': 0.24070917149676099, 'auc': 0.21313960502504653, 'false positive': 1.0, 'time': 71.16686391830444}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 16.206897020339966}
# {'false negative': 0.16143344709897611, 'auc': 0.13254292465213968, 'false positive': 1.0, 'time': 91.80335402488708}
# {'false negative': 0.1295601772928742, 'auc': 0.77081591439586672, 'false positive': 0.7630769230769231, 'time': 43.394997119903564}
# {'false negative': 0.50903511762700304, 'auc': 0.81641794959217395, 'false positive': 0.0061538461538461538, 'time': 21.692357063293457}
# {'false negative': 0.437436072280941, 'auc': 0.91515224632169734, 'false positive': 0.0061538461538461538, 'time': 13.420087814331055}
# {'false negative': 0.98772587794067512, 'auc': 0.99957827375488473, 'false positive': 0.0, 'time': 22.823029041290283}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 4.998326063156128}
# {'false negative': 0.24445959768155473, 'auc': 0.79589393899656435, 'false positive': 0.30769230769230771, 'time': 35.725258111953735}
# {'false negative': 1.0, 'auc': 0.50238663484486878, 'false positive': 0.0, 'time': 15.207803010940552}
# {'false negative': 1.0, 'auc': 0.50136379133992504, 'false positive': 0.0, 'time': 3.2504429817199707}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 3.7775328159332275}
# {'false negative': 0.21569965870307167, 'auc': 0.71973326332370702, 'false positive': 0.66461538461538461, 'time': 61.65111994743347}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 94.5073721408844}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 11.44731593132019}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 59.50862693786621}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 3.789362907409668}
# {'false negative': 0.83804977838390726, 'auc': 0.99073775866138625, 'false positive': 0.0, 'time': 6.913393020629883}
# {'false negative': 0.81213774292533247, 'auc': 0.96154842770594562, 'false positive': 0.0, 'time': 12.992238998413086}
# {'false negative': 0.45721104670985341, 'auc': 0.28347032442497838, 'false positive': 0.98153846153846158, 'time': 63.76292681694031}
# {'false negative': 0.16570064780088647, 'auc': 0.68454037609168872, 'false positive': 0.88923076923076927, 'time': 61.66712307929993}
# {'false negative': 0.25775656324582341, 'auc': 0.23759553096068609, 'false positive': 1.0, 'time': 78.32735800743103}
# {'false negative': 0.61541084214115238, 'auc': 0.12527892155577119, 'false positive': 1.0, 'time': 91.07230401039124}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 59.44347810745239}
# {'false negative': 1.0, 'auc': 0.97147577959033804, 'false positive': 0.0, 'time': 86.3129460811615}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 40.97307991981506}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 88.03136587142944}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 22.440460920333862}
# {'false negative': 1.0, 'auc': 0.97012698079546644, 'false positive': 0.0, 'time': 82.27071285247803}
# {'false negative': 0.10538881309686221, 'auc': 0.67718648336656528, 'false positive': 0.98769230769230765, 'time': 69.7556700706482}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 88.9290452003479}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 63.9853789806366}
# {'false negative': 0.20382383065892795, 'auc': 0.96409170890563844, 'false positive': 0.0030769230769230769, 'time': 52.109127044677734}
# {'false negative': 0.89290586630286495, 'auc': 0.994185119110085, 'false positive': 0.0, 'time': 8.88532304763794}
# {'false negative': 0.12256742915670878, 'auc': 0.22254589384667911, 'false positive': 1.0, 'time': 73.63047003746033}
# {'false negative': 0.10917775503241214, 'auc': 0.48007348502742564, 'false positive': 1.0, 'time': 66.4442310333252}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 80.40595889091492}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 81.82210993766785}
# {'false negative': 0.042320819112627986, 'auc': 0.99420110265161465, 'false positive': 0.018461538461538463, 'time': 11.183833122253418}
# {'false negative': 0.99965905216501871, 'auc': 0.99985417923365416, 'false positive': 0.0, 'time': 17.143606901168823}
# {'false negative': 1.0, 'auc': 0.51636549607909987, 'false positive': 0.0, 'time': 39.34548211097717}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 25.788060903549194}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 3.564133882522583}
# {'false negative': 0.046757679180887371, 'auc': 0.99738199002362815, 'false positive': 0.0092307692307692316, 'time': 6.8367578983306885}
# {'false negative': 1.0, 'auc': 0.99816140203589032, 'false positive': 0.0, 'time': 53.311527967453}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 37.22985601425171}
# {'false negative': 0.58935879945429737, 'auc': 0.98612970930842703, 'false positive': 0.0, 'time': 27.869158029556274}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 14.666431903839111}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 7.77150297164917}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 84.66869783401489}
# {'false negative': 0.059324923286737129, 'auc': 0.97488630701041201, 'false positive': 0.040000000000000001, 'time': 3.324965000152588}
# {'false negative': 0.77020115922263899, 'auc': 0.99194418946208929, 'false positive': 0.0, 'time': 6.7708070278167725}
# {'false negative': 0.071282401091405184, 'auc': 0.27291741001154368, 'false positive': 1.0, 'time': 73.6146149635315}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 66.37119197845459}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 19.843129873275757}
# {'false negative': 0.4353903852710535, 'auc': 0.11011041464502086, 'false positive': 1.0, 'time': 82.56187891960144}
# {'false negative': 0.96692806000681897, 'auc': 0.97676519184872412, 'false positive': 0.0030769230769230769, 'time': 3.6672449111938477}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 69.63925695419312}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 68.88748598098755}
# {'false negative': 0.035458574838049775, 'auc': 0.99994335020587999, 'false positive': 0.0, 'time': 13.589550971984863}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 60.26717185974121}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 62.56294393539429}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 60.639532804489136}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 101.83294606208801}
# {'false negative': 0.090010228435049439, 'auc': 0.63977025361273565, 'false positive': 0.99692307692307691, 'time': 74.97096490859985}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 90.47882008552551}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 91.95624899864197}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 113.5277750492096}
# {'false negative': 0.86527967257844474, 'auc': 0.98841956133907027, 'false positive': 0.0, 'time': 16.54693603515625}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 80.62882208824158}
# {'false negative': 1.0, 'auc': 0.99829526082509368, 'false positive': 0.0, 'time': 12.039467096328735}
# {'false negative': 0.68019093078758952, 'auc': 0.094704817855175857, 'false positive': 1.0, 'time': 94.45588493347168}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 55.73261594772339}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 58.823325872421265}
# {'false negative': 1.0, 'auc': 0.50051142175247187, 'false positive': 0.0, 'time': 3.743614912033081}
# {'false negative': 0.2400272758267985, 'auc': 0.99850297673686694, 'false positive': 0.0, 'time': 8.092792987823486}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 96.80766487121582}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 7.1440229415893555}
# {'false negative': 1.0, 'auc': 0.50153478854024558, 'false positive': 0.0, 'time': 27.36424994468689}
# {'false negative': 1.0, 'auc': 0.50017047391749059, 'false positive': 0.0, 'time': 3.5563039779663086}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 17.008219003677368}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 20.070223093032837}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 30.94672203063965}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 46.25999593734741}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 28.960792064666748}
# {'false negative': 0.32662802591203544, 'auc': 0.99375908101445098, 'false positive': 0.0030769230769230769, 'time': 14.046779155731201}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 15.623230218887329}
# {'false negative': 0.97408796454142521, 'auc': 0.61609273781111495, 'false positive': 0.0, 'time': 3.5435991287231445}
# {'false negative': 1.0, 'auc': 0.96785701172336025, 'false positive': 0.0, 'time': 8.27948808670044}
# {'false negative': 1.0, 'auc': 0.98607569041936594, 'false positive': 0.0, 'time': 3.519542932510376}
# {'false negative': 1.0, 'auc': 0.5, 'false positive': 0.0, 'time': 7.504436016082764}

# %%
data = generate_dataset(1000, dim=7)
all_gammas = np.logspace(-15, 15, 50)

# %%
values = model_selection(data.iloc[:, :-1], all_gammas, validate_classifier_by_random_points)

# %%
plot(all_gammas, values)
xscale('log')
#yscale('log')

# %%
print values
# Out:
# [  8.25153299e+14   2.01486292e+14   4.92048272e+13   1.20161052e+13
#    2.93439289e+12   7.16594319e+11   1.74996139e+11   4.27349904e+10
#    1.04361158e+10   2.54855918e+09   6.22375978e+08   1.51991813e+08
#    3.71215020e+07   9.06956291e+06   2.21913290e+06   5.46231595e+05
#    1.37741046e+05   3.81456449e+04   1.43678579e+04   9.67539573e+03
#    9.28544792e+03   9.14996847e+03   9.05449559e+03   9.03833655e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03   9.03832742e+03   9.03832742e+03
#    9.03832742e+03   9.03832742e+03]
